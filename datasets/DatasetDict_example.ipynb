# %%
# %pip install --upgrade datasets evaluate transformers

# %% [markdown]
# # Download dataset

# %% [markdown]
# * datasets.load_dataset
#  https://huggingface.co/docs/datasets/v2.15.0/en/package_reference/loading_methods#datasets.load_dataset

# %%
# available datasets
from huggingface_hub import list_datasets

available_datasets = list_datasets() # generator
dataset_infos = list (available_datasets) # list
dataset_infos
# Out:
# [DatasetInfo(id='acronym_identification', author=None, sha='c3c245a18bbd57b1682b099e14460eebf154cbdf', last_modified=datetime.datetime(2023, 1, 25, 14, 18, 28, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=1186, likes=17, paperswithcode_id='acronym-identification', tags=['task_categories:token-classification', 'annotations_creators:expert-generated', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:10K<n<100K', 'source_datasets:original', 'language:en', 'license:mit', 'acronym-identification', 'arxiv:2010.14678', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='ade_corpus_v2', author=None, sha='080cf99e1483008322d612c7262c04c8902fdbee', last_modified=datetime.datetime(2023, 6, 1, 14, 59, 53, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=1679, likes=20, paperswithcode_id=None, tags=['task_categories:text-classification', 'task_categories:token-classification', 'task_ids:coreference-resolution', 'task_ids:fact-checking', 'annotations_creators:expert-generated', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:10K<n<100K', 'size_categories:1K<n<10K', 'size_categories:n<1K', 'source_datasets:original', 'language:en', 'license:unknown', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='adversarial_qa', author=None, sha='2101a4597c2b5517902e2eef903c47b2caedacd8', last_modified=datetime.datetime(2022, 11, 18, 17, 31, 37, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=3455, likes=30, paperswithcode_id='adversarialqa', tags=['task_categories:question-answering', 'task_ids:extractive-qa', 'task_ids:open-domain-qa', 'annotations_creators:crowdsourced', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:10K<n<100K', 'source_datasets:original', 'language:en', 'license:cc-by-sa-4.0', 'arxiv:2002.00293', 'arxiv:1606.05250', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='aeslc', author=None, sha='28d4d3a046750bf18995a77dfb9f5f082fe837f6', last_modified=datetime.datetime(2023, 4, 5, 8, 32, 58, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=3028, likes=6, paperswithcode_id='aeslc', tags=['task_categories:summarization', 'annotations_creators:crowdsourced', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:10K<n<100K', 'source_datasets:original', 'language:en', 'license:unknown', 'aspect-based-summarization', 'conversations-summarization', 'multi-document-summarization', 'email-headline-generation', 'arxiv:1906.03497', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='afrikaans_ner_corpus', author=None, sha='58eb3b7ec689e17d42ffd858b8e514cbd0ffbc7f', last_modified=datetime.datetime(2023, 1, 25, 14, 20, 30, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=387, likes=3, paperswithcode_id=None, tags=['task_categories:token-classification', 'task_ids:named-entity-recognition', 'annotations_creators:expert-generated', 'language_creators:expert-generated', 'multilinguality:monolingual', 'size_categories:1K<n<10K', 'source_datasets:original', 'language:af', 'license:other', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='ag_news', author=None, sha='3dcafdc56638659831698aaa2348334a5ab44513', last_modified=datetime.datetime(2023, 4, 5, 8, 34, 57, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=43007, likes=84, paperswithcode_id='ag-news', tags=['task_categories:text-classification', 'task_ids:topic-classification', 'annotations_creators:found', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:100K<n<1M', 'source_datasets:original', 'language:en', 'license:unknown', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='ai2_arc', author=None, sha='870fda1dc455fb8aec468816fb61c29c602c21ba', last_modified=datetime.datetime(2023, 4, 5, 9, 11, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=409046, likes=38, paperswithcode_id=None, tags=['task_categories:question-answering', 'task_ids:open-domain-qa', 'task_ids:multiple-choice-qa', 'annotations_creators:found', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:1K<n<10K', 'source_datasets:original', 'language:en', 'license:cc-by-sa-4.0', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='air_dialogue', author=None, sha='3ef284c2b1ca63cebd46335641fa31b09763f4e5', last_modified=datetime.datetime(2022, 11, 3, 16, 31, 11, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=342, likes=6, paperswithcode_id=None, tags=['task_categories:conversational', 'task_categories:text-generation', 'task_categories:fill-mask', 'task_ids:dialogue-generation', 'task_ids:dialogue-modeling', 'task_ids:language-modeling', 'task_ids:masked-language-modeling', 'annotations_creators:crowdsourced', 'language_creators:machine-generated', 'multilinguality:monolingual', 'size_categories:100K<n<1M', 'source_datasets:original', 'language:en', 'license:cc-by-nc-4.0', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='ajgt_twitter_ar', author=None, sha='8016dcbb32739004bd1fc36dd0bcc97381dcb7f1', last_modified=datetime.datetime(2023, 1, 25, 14, 26, 5, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=333, likes=3, paperswithcode_id=None, tags=['task_categories:text-classification', 'task_ids:sentiment-classification', 'annotations_creators:found', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:1K<n<10K', 'source_datasets:original', 'language:ar', 'license:unknown', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='allegro_reviews', author=None, sha='640d5c0c0cf44fba49bfa7fd4d29e7feb51bde21', last_modified=datetime.datetime(2022, 11, 18, 17, 41, 41, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=309, likes=1, paperswithcode_id='allegro-reviews', tags=['task_categories:text-classification', 'task_ids:sentiment-scoring', 'task_ids:text-scoring', 'annotations_creators:found', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:10K<n<100K', 'source_datasets:original', 'language:pl', 'license:cc-by-sa-4.0', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='allocine', author=None, sha='c090a3d204bed7b4a51adaaa6c1fe638cf9246c1', last_modified=datetime.datetime(2023, 1, 25, 14, 26, 9, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=1633, likes=6, paperswithcode_id='allocine', tags=['task_categories:text-classification', 'task_ids:sentiment-classification', 'annotations_creators:no-annotation', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:100K<n<1M', 'source_datasets:original', 'language:fr', 'license:mit', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='alt', author=None, sha='1e036053e9a853af165ad831f6797a1247307f5a', last_modified=datetime.datetime(2023, 6, 1, 14, 59, 53, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=1250, likes=7, paperswithcode_id='alt', tags=['task_categories:translation', 'task_categories:token-classification', 'task_ids:parsing', 'annotations_creators:expert-generated', 'language_creators:crowdsourced', 'multilinguality:multilingual', 'multilinguality:translation', 'size_categories:100K<n<1M', 'size_categories:10K<n<100K', 'source_datasets:original', 'language:bn', 'language:en', 'language:fil', 'language:hi', 'language:id', 'language:ja', 'language:km', 'language:lo', 'language:ms', 'language:my', 'language:th', 'language:vi', 'language:zh', 'license:cc-by-4.0', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='amazon_polarity', author=None, sha='b19c47c74e5660014c166f3e0978b5c449718d5a', last_modified=datetime.datetime(2023, 1, 25, 14, 26, 12, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=19222, likes=30, paperswithcode_id=None, tags=['task_categories:text-classification', 'task_ids:sentiment-classification', 'annotations_creators:crowdsourced', 'language_creators:crowdsourced', 'multilinguality:monolingual', 'size_categories:1M<n<10M', 'source_datasets:original', 'language:en', 'license:apache-2.0', 'arxiv:1509.01626', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='amazon_reviews_multi', author=None, sha='b6115b04af1d02b3c30849bdd4c55899bff0ae63', last_modified=datetime.datetime(2023, 11, 2, 14, 52, 21, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=2021, likes=82, paperswithcode_id=None, tags=['task_categories:summarization', 'task_categories:text-generation', 'task_categories:fill-mask', 'task_categories:text-classification', 'task_ids:text-scoring', 'task_ids:language-modeling', 'task_ids:masked-language-modeling', 'task_ids:sentiment-classification', 'task_ids:sentiment-scoring', 'task_ids:topic-classification', 'annotations_creators:found', 'language_creators:found', 'multilinguality:monolingual', 'multilinguality:multilingual', 'size_categories:100K<n<1M', 'size_categories:1M<n<10M', 'source_datasets:original', 'language:de', 'language:en', 'language:es', 'language:fr', 'language:ja', 'language:zh', 'license:other', 'arxiv:2010.02573', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='amazon_us_reviews', author=None, sha='e1bfd57e2da5dc7dc4c748eb4a4a112c71e85162', last_modified=datetime.datetime(2023, 11, 2, 14, 57, 3, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=5463, likes=56, paperswithcode_id=None, tags=['task_categories:summarization', 'task_categories:text-generation', 'task_categories:fill-mask', 'task_categories:text-classification', 'task_ids:text-scoring', 'task_ids:language-modeling', 'task_ids:masked-language-modeling', 'task_ids:sentiment-classification', 'task_ids:sentiment-scoring', 'task_ids:topic-classification', 'annotations_creators:no-annotation', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:100M<n<1B', 'source_datasets:original', 'language:en', 'license:other', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='ambig_qa', author=None, sha='4b3c61e4acf755a804e74bc7186e2599ecec36ad', last_modified=datetime.datetime(2022, 11, 3, 16, 31, 34, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=702, likes=3, paperswithcode_id='ambigqa', tags=['task_categories:question-answering', 'task_ids:open-domain-qa', 'annotations_creators:crowdsourced', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:10K<n<100K', 'source_datasets:extended|natural_questions', 'source_datasets:original', 'language:en', 'license:cc-by-sa-3.0', 'arxiv:2004.10645', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='americas_nli', author=None, sha='e0b2b54a22e1987d4df45035bd0d354ac0d16d2b', last_modified=datetime.datetime(2023, 1, 25, 14, 26, 20, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=2110, likes=1, paperswithcode_id=None, tags=['task_categories:text-classification', 'task_ids:natural-language-inference', 'annotations_creators:expert-generated', 'language_creators:expert-generated', 'multilinguality:multilingual', 'multilinguality:translation', 'size_categories:unknown', 'source_datasets:extended|xnli', 'language:ay', 'language:bzd', 'language:cni', 'language:gn', 'language:hch', 'language:nah', 'language:oto', 'language:qu', 'language:shp', 'language:tar', 'license:unknown', 'arxiv:2104.08726', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='ami', author=None, sha='0774a5e0099ba9696b9ba00bc3be025d4bb31ccd', last_modified=datetime.datetime(2023, 1, 17, 13, 44, 21, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=862, likes=9, paperswithcode_id=None, tags=['task_categories:automatic-speech-recognition', 'annotations_creators:expert-generated', 'language_creators:crowdsourced', 'language_creators:expert-generated', 'multilinguality:monolingual', 'size_categories:100K<n<1M', 'source_datasets:original', 'language:en', 'license:cc-by-4.0', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='amttl', author=None, sha='2c63d54ff21178fe036fb45ed7f2dcb6c0872b15', last_modified=datetime.datetime(2023, 1, 25, 14, 26, 23, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=247, likes=1, paperswithcode_id=None, tags=['task_categories:token-classification', 'task_ids:parsing', 'annotations_creators:crowdsourced', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:1K<n<10K', 'source_datasets:original', 'language:zh', 'license:mit', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='anli', author=None, sha='bf206833154d4fcaf5e3b01b8bf17d4d15213cb1', last_modified=datetime.datetime(2023, 4, 5, 9, 33, 23, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=15230, likes=23, paperswithcode_id='anli', tags=['task_categories:text-classification', 'task_ids:natural-language-inference', 'task_ids:multi-input-text-classification', 'annotations_creators:crowdsourced', 'annotations_creators:machine-generated', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:100K<n<1M', 'source_datasets:original', 'source_datasets:extended|hotpot_qa', 'language:en', 'license:cc-by-nc-4.0', 'arxiv:1910.14599', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='app_reviews', author=None, sha='0ca262730c1edb7abe4c500005216da26d9b7374', last_modified=datetime.datetime(2022, 11, 3, 16, 47, 21, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=2811, likes=18, paperswithcode_id=None, tags=['task_categories:text-classification', 'task_ids:text-scoring', 'task_ids:sentiment-scoring', 'annotations_creators:crowdsourced', 'language_creators:crowdsourced', 'multilinguality:monolingual', 'size_categories:100K<n<1M', 'source_datasets:original', 'language:en', 'license:unknown', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='aqua_rat', author=None, sha='a5c302cb30cd42c0cd0d5f60a89e81ae65bb13d5', last_modified=datetime.datetime(2022, 11, 18, 18, 20, 44, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=1815, likes=9, paperswithcode_id='aqua-rat', tags=['task_categories:question-answering', 'task_ids:multiple-choice-qa', 'annotations_creators:crowdsourced', 'language_creators:crowdsourced', 'language_creators:expert-generated', 'multilinguality:monolingual', 'size_categories:10K<n<100K', 'source_datasets:original', 'language:en', 'license:apache-2.0', 'arxiv:1705.04146', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='aquamuse', author=None, sha='df0c4edce17524955ffcbdc7efb2a2aa7cafa0a1', last_modified=datetime.datetime(2022, 11, 18, 18, 21, 11, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=180, likes=9, paperswithcode_id='aquamuse', tags=['task_categories:other', 'task_categories:question-answering', 'task_categories:text2text-generation', 'task_ids:abstractive-qa', 'task_ids:extractive-qa', 'annotations_creators:crowdsourced', 'annotations_creators:expert-generated', 'language_creators:crowdsourced', 'language_creators:expert-generated', 'multilinguality:monolingual', 'size_categories:1K<n<10K', 'source_datasets:extended|natural_questions', 'source_datasets:extended|other-Common-Crawl', 'source_datasets:original', 'language:en', 'license:unknown', 'query-based-multi-document-summarization', 'arxiv:2010.12694', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='bigIR/ar_cov19', author='bigIR', sha='447b2a5a20c9e8ffaee0f14b31697be7b0dec403', last_modified=datetime.datetime(2023, 9, 19, 6, 52, 17, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=242, likes=1, paperswithcode_id='arcov-19', tags=['task_categories:other', 'annotations_creators:no-annotation', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:1M<n<10M', 'source_datasets:original', 'language:ar', 'data-mining', 'arxiv:2004.05861', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='ar_res_reviews', author=None, sha='c00a78aca90ab394a6dad315f331b1bb8875b08c', last_modified=datetime.datetime(2023, 1, 25, 14, 26, 30, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=264, likes=5, paperswithcode_id=None, tags=['task_categories:text-classification', 'task_ids:sentiment-classification', 'annotations_creators:found', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:1K<n<10K', 'source_datasets:original', 'language:ar', 'license:unknown', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='ar_sarcasm', author=None, sha='8ed550e17740a8045feaeb8dff398fff6eb3372a', last_modified=datetime.datetime(2023, 3, 16, 14, 13, 22, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=267, likes=8, paperswithcode_id=None, tags=['task_categories:text-classification', 'task_ids:sentiment-classification', 'annotations_creators:no-annotation', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:10K<n<100K', 'source_datasets:extended|other-semeval_2017', 'source_datasets:extended|other-astd', 'language:ar', 'license:mit', 'sarcasm-detection', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='arabic_billion_words', author=None, sha='aeb210f8a0665bfb3aba23e91f82aa6e78d0c8e6', last_modified=datetime.datetime(2023, 6, 1, 14, 59, 53, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=1101, likes=13, paperswithcode_id=None, tags=['task_categories:text-generation', 'task_categories:fill-mask', 'task_ids:language-modeling', 'task_ids:masked-language-modeling', 'annotations_creators:found', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:100K<n<1M', 'size_categories:10K<n<100K', 'size_categories:1M<n<10M', 'source_datasets:original', 'language:ar', 'license:unknown', 'arxiv:1611.04033', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='arabic_pos_dialect', author=None, sha='1c36271a1adad5a8b8feb131d44e6fadab5185c8', last_modified=datetime.datetime(2022, 11, 3, 16, 31, 33, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=614, likes=2, paperswithcode_id=None, tags=['task_categories:token-classification', 'task_ids:part-of-speech', 'annotations_creators:expert-generated', 'language_creators:found', 'multilinguality:multilingual', 'size_categories:n<1K', 'source_datasets:extended', 'language:ar', 'license:apache-2.0', 'arxiv:1708.05891', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='arabic_speech_corpus', author=None, sha='0ce1cc248c8d909e8581677db6096c5565447173', last_modified=datetime.datetime(2022, 11, 18, 18, 29, 9, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=1061, likes=17, paperswithcode_id='arabic-speech-corpus', tags=['task_categories:automatic-speech-recognition', 'annotations_creators:expert-generated', 'language_creators:crowdsourced', 'multilinguality:monolingual', 'size_categories:1K<n<10K', 'source_datasets:original', 'language:ar', 'license:cc-by-4.0', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='arcd', author=None, sha='cf18961d83b615154ef5feda04e324136db8c4ac', last_modified=datetime.datetime(2023, 4, 5, 9, 35, 12, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=393, likes=3, paperswithcode_id='arcd', tags=['task_categories:question-answering', 'task_ids:extractive-qa', 'annotations_creators:crowdsourced', 'language_creators:crowdsourced', 'multilinguality:monolingual', 'size_categories:1K<n<10K', 'source_datasets:original', 'language:ar', 'license:mit', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='arsentd_lev', author=None, sha='028b279dab19c1e411f942cc922d70bb17b19c25', last_modified=datetime.datetime(2023, 1, 25, 14, 26, 36, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=197, likes=3, paperswithcode_id='arsentd-lev', tags=['task_categories:text-classification', 'task_ids:sentiment-classification', 'task_ids:topic-classification', 'annotations_creators:crowdsourced', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:1K<n<10K', 'source_datasets:original', 'language:apc', 'language:ajp', 'license:other', 'arxiv:1906.01830', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='art', author=None, sha='1ac0124f79d0b65499bbf0a2395e27901c3eba1d', last_modified=datetime.datetime(2023, 4, 5, 9, 36, 25, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=499, likes=4, paperswithcode_id='art-dataset', tags=['task_categories:multiple-choice', 'task_categories:text-classification', 'task_ids:natural-language-inference', 'annotations_creators:crowdsourced', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:100K<n<1M', 'source_datasets:original', 'language:en', 'license:unknown', 'abductive-natural-language-inference', 'arxiv:1908.05739', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='arxiv_dataset', author=None, sha='03f5afc04118f5d2599283e577584ddb3416f9b2', last_modified=datetime.datetime(2023, 10, 26, 10, 45, 45, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=419, likes=43, paperswithcode_id=None, tags=['task_categories:translation', 'task_categories:summarization', 'task_categories:text-retrieval', 'task_ids:document-retrieval', 'task_ids:entity-linking-retrieval', 'task_ids:explanation-generation', 'task_ids:fact-checking-retrieval', 'task_ids:text-simplification', 'annotations_creators:no-annotation', 'language_creators:expert-generated', 'multilinguality:monolingual', 'size_categories:1M<n<10M', 'source_datasets:original', 'language:en', 'license:cc0-1.0', 'arxiv:1905.00075', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='ascent_kb', author=None, sha='3d1fe338bc0a449c4b6ccaa0f31674ed32096231', last_modified=datetime.datetime(2022, 11, 3, 16, 30, 39, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=367, likes=2, paperswithcode_id='ascentkb', tags=['task_categories:other', 'annotations_creators:found', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:1M<n<10M', 'source_datasets:original', 'language:en', 'license:cc-by-4.0', 'knowledge-base', 'arxiv:2011.00905', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='aslg_pc12', author=None, sha='4e0d9bd4e7f3529509603684b26156d618160d8c', last_modified=datetime.datetime(2023, 4, 5, 9, 36, 28, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=410, likes=3, paperswithcode_id='aslg-pc12', tags=['task_categories:translation', 'annotations_creators:crowdsourced', 'annotations_creators:expert-generated', 'language_creators:found', 'multilinguality:translation', 'size_categories:10K<n<100K', 'source_datasets:original', 'language:ase', 'language:en', 'license:cc-by-nc-4.0', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='asnq', author=None, sha='772b8e0cc903548bc34b9af7872a64e13345e900', last_modified=datetime.datetime(2023, 5, 16, 8, 28, 22, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=369, likes=1, paperswithcode_id='asnq', tags=['task_categories:multiple-choice', 'task_ids:multiple-choice-qa', 'annotations_creators:crowdsourced', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:10M<n<100M', 'source_datasets:extended|natural_questions', 'language:en', 'license:cc-by-nc-sa-3.0', 'arxiv:1911.04118', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='asset', author=None, sha='b44bea65d455281810ee9c167a55629ac85ace33', last_modified=datetime.datetime(2023, 6, 1, 14, 59, 51, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=714, likes=9, paperswithcode_id='asset', tags=['task_categories:text-classification', 'task_categories:text2text-generation', 'task_ids:text-simplification', 'annotations_creators:machine-generated', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:1K<n<10K', 'source_datasets:original', 'source_datasets:extended|other-turkcorpus', 'language:en', 'license:cc-by-sa-4.0', 'simplification-evaluation', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='assin', author=None, sha='c69f21213a28d2c0ee5e7d9aca908dfebe09eda0', last_modified=datetime.datetime(2023, 1, 25, 14, 26, 50, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=628, likes=8, paperswithcode_id='assin', tags=['task_categories:text-classification', 'task_ids:text-scoring', 'task_ids:natural-language-inference', 'task_ids:semantic-similarity-scoring', 'annotations_creators:expert-generated', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:10K<n<100K', 'source_datasets:original', 'language:pt', 'license:unknown', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='assin2', author=None, sha='2ec4bf3f58b49faf9026e0548d94bcb7fc947304', last_modified=datetime.datetime(2023, 1, 25, 14, 26, 53, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=942, likes=9, paperswithcode_id='assin2', tags=['task_categories:text-classification', 'task_ids:text-scoring', 'task_ids:natural-language-inference', 'task_ids:semantic-similarity-scoring', 'annotations_creators:expert-generated', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:1K<n<10K', 'source_datasets:original', 'language:pt', 'license:unknown', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='atomic', author=None, sha='c1d0d9ce67e77e5826cd7768c976a9b1ce9e5a05', last_modified=datetime.datetime(2022, 11, 18, 18, 56, 37, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=204, likes=6, paperswithcode_id='atomic', tags=['task_categories:text2text-generation', 'annotations_creators:crowdsourced', 'language_creators:crowdsourced', 'multilinguality:monolingual', 'size_categories:100K<n<1M', 'source_datasets:original', 'language:en', 'license:cc-by-4.0', 'common-sense-if-then-reasoning', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='autshumato', author=None, sha='9e0ec3cdda321375d063ee1116e6b4fdb96898cf', last_modified=datetime.datetime(2023, 6, 1, 14, 59, 51, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=688, likes=2, paperswithcode_id=None, tags=['task_categories:translation', 'annotations_creators:expert-generated', 'language_creators:expert-generated', 'multilinguality:multilingual', 'size_categories:100K<n<1M', 'size_categories:10K<n<100K', 'source_datasets:original', 'language:en', 'language:tn', 'language:ts', 'language:zu', 'license:cc-by-2.5', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='facebook/babi_qa', author='facebook', sha='021d7aeb7307b7856dd0632f92827bc607dc2f1b', last_modified=datetime.datetime(2023, 1, 25, 14, 26, 58, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=1559, likes=5, paperswithcode_id='babi-1', tags=['task_categories:question-answering', 'annotations_creators:machine-generated', 'language_creators:machine-generated', 'multilinguality:monolingual', 'size_categories:10K<n<100K', 'size_categories:1K<n<10K', 'size_categories:n<1K', 'source_datasets:original', 'language:en', 'license:cc-by-3.0', 'chained-qa', 'arxiv:1502.05698', 'arxiv:1511.06931', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='banking77', author=None, sha='d85bf5785707deabf276bf2dbcfe68f43ea8d20d', last_modified=datetime.datetime(2023, 4, 17, 13, 46, 23, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=5303, likes=26, paperswithcode_id=None, tags=['task_categories:text-classification', 'task_ids:intent-classification', 'task_ids:multi-class-classification', 'annotations_creators:expert-generated', 'language_creators:expert-generated', 'multilinguality:monolingual', 'size_categories:10K<n<100K', 'source_datasets:original', 'language:en', 'license:cc-by-4.0', 'arxiv:2003.04807', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='bbaw_egyptian', author=None, sha='42a1c1473b56e56db7ed985d1b35c284e840fd14', last_modified=datetime.datetime(2023, 4, 5, 9, 36, 39, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=243, likes=5, paperswithcode_id=None, tags=['task_categories:translation', 'annotations_creators:expert-generated', 'language_creators:found', 'multilinguality:multilingual', 'size_categories:100K<n<1M', 'source_datasets:extended|wikipedia', 'language:de', 'language:egy', 'language:en', 'license:cc-by-4.0', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='bbc_hindi_nli', author=None, sha='ff897a19c2a26f64106b44e86b7a59fcf72217ee', last_modified=datetime.datetime(2023, 1, 25, 14, 27, 6, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=569, likes=0, paperswithcode_id=None, tags=['task_categories:text-classification', 'task_ids:natural-language-inference', 'annotations_creators:machine-generated', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:10K<n<100K', 'source_datasets:extended|bbc__hindi_news_classification', 'language:hi', 'license:mit', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='bc2gm_corpus', author=None, sha='fe41a26f473deec2c1fd9c5c9f3518dd0bfab16f', last_modified=datetime.datetime(2023, 8, 30, 12, 13, 12, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=538, likes=5, paperswithcode_id=None, tags=['task_categories:token-classification', 'task_ids:named-entity-recognition', 'annotations_creators:expert-generated', 'language_creators:expert-generated', 'multilinguality:monolingual', 'size_categories:10K<n<100K', 'source_datasets:original', 'language:en', 'license:unknown', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='beans', author=None, sha='ff99f4013946ad6c578bd070712b10fa0664fc9f', last_modified=datetime.datetime(2023, 1, 25, 14, 27, 13, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=12836, likes=17, paperswithcode_id=None, tags=['task_categories:image-classification', 'task_ids:multi-class-image-classification', 'annotations_creators:expert-generated', 'language_creators:expert-generated', 'multilinguality:monolingual', 'size_categories:1K<n<10K', 'source_datasets:original', 'language:en', 'license:mit', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='best2009', author=None, sha='cb854e4aafa7d4715c9181daeec70ccfe916ac48', last_modified=datetime.datetime(2023, 1, 25, 14, 27, 17, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=237, likes=0, paperswithcode_id=None, tags=['task_categories:token-classification', 'annotations_creators:expert-generated', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:100K<n<1M', 'source_datasets:original', 'language:th', 'license:cc-by-nc-sa-3.0', 'word-tokenization', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='bianet', author=None, sha='c2f33d069ae69d58adfe50d65f520786921936a4', last_modified=datetime.datetime(2023, 6, 1, 14, 59, 50, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=488, likes=1, paperswithcode_id='bianet', tags=['task_categories:translation', 'annotations_creators:found', 'language_creators:found', 'multilinguality:translation', 'size_categories:10K<n<100K', 'size_categories:1K<n<10K', 'source_datasets:original', 'language:en', 'language:ku', 'language:tr', 'license:unknown', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='bible_para', author=None, sha='2e74af6334810a0b4b06b7915b331996526ef538', last_modified=datetime.datetime(2022, 11, 3, 16, 31, 57, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=1899, likes=12, paperswithcode_id=None, tags=['task_categories:translation', 'annotations_creators:found', 'language_creators:found', 'multilinguality:multilingual', 'size_categories:10K<n<100K', 'source_datasets:original', 'language:acu', 'language:af', 'language:agr', 'language:ake', 'language:am', 'language:amu', 'language:ar', 'language:bg', 'language:bsn', 'language:cak', 'language:ceb', 'language:ch', 'language:chq', 'language:chr', 'language:cjp', 'language:cni', 'language:cop', 'language:crp', 'language:cs', 'language:da', 'language:de', 'language:dik', 'language:dje', 'language:djk', 'language:dop', 'language:ee', 'language:el', 'language:en', 'language:eo', 'language:es', 'language:et', 'language:eu', 'language:fi', 'language:fr', 'language:gbi', 'language:gd', 'language:gu', 'language:gv', 'language:he', 'language:hi', 'language:hr', 'language:hu', 'language:hy', 'language:id', 'language:is', 'language:it', 'language:ja', 'language:jak', 'language:jiv', 'language:kab', 'language:kbh', 'language:kek', 'language:kn', 'language:ko', 'language:la', 'language:lt', 'language:lv', 'language:mam', 'language:mi', 'language:ml', 'language:mr', 'language:my', 'language:ne', 'language:nhg', 'language:nl', 'language:no', 'language:ojb', 'language:pck', 'language:pes', 'language:pl', 'language:plt', 'language:pot', 'language:ppk', 'language:pt', 'language:quc', 'language:quw', 'language:ro', 'language:rom', 'language:ru', 'language:shi', 'language:sk', 'language:sl', 'language:sn', 'language:so', 'language:sq', 'language:sr', 'language:ss', 'language:sv', 'language:syr', 'language:te', 'language:th', 'language:tl', 'language:tmh', 'language:tr', 'language:uk', 'language:usp', 'language:vi', 'language:wal', 'language:wo', 'language:xh', 'language:zh', 'language:zu', 'license:cc0-1.0', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='big_patent', author=None, sha='cc72d536615ac5aede5ab536a01d194389391f8d', last_modified=datetime.datetime(2023, 6, 1, 14, 59, 54, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=2505, likes=28, paperswithcode_id='bigpatent', tags=['task_categories:summarization', 'annotations_creators:no-annotation', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:100K<n<1M', 'size_categories:10K<n<100K', 'size_categories:1M<n<10M', 'source_datasets:original', 'language:en', 'license:cc-by-4.0', 'patent-summarization', 'arxiv:1906.03741', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='billsum', author=None, sha='b622e61e3a575199f6fe44021faf9ecbbddbb40d', last_modified=datetime.datetime(2023, 4, 5, 9, 41, 39, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=3946, likes=21, paperswithcode_id='billsum', tags=['task_categories:summarization', 'annotations_creators:found', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:10K<n<100K', 'source_datasets:original', 'language:en', 'license:cc0-1.0', 'bills-summarization', 'arxiv:1910.00523', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='bing_coronavirus_query_set', author=None, sha='52dc8b2b3516ff47aaa5c833f2df8a17a1e8516d', last_modified=datetime.datetime(2022, 11, 3, 16, 30, 54, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=263, likes=0, paperswithcode_id=None, tags=['task_categories:text-classification', 'task_ids:intent-classification', 'annotations_creators:found', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:100K<n<1M', 'source_datasets:original', 'language:en', 'license:other', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='biomrc', author=None, sha='504a2603c5da9fcbb064e50f74ffd4803fc4700d', last_modified=datetime.datetime(2023, 4, 5, 9, 41, 42, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=1046, likes=4, paperswithcode_id='biomrc', tags=['language:en', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='biosses', author=None, sha='41a7d298fb653c08143706f4542dad04bebcd337', last_modified=datetime.datetime(2022, 11, 3, 16, 31, 20, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=1947, likes=4, paperswithcode_id='biosses', tags=['task_categories:text-classification', 'task_ids:text-scoring', 'task_ids:semantic-similarity-scoring', 'annotations_creators:expert-generated', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:n<1K', 'source_datasets:original', 'language:en', 'license:gpl-3.0', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='TheBritishLibrary/blbooks', author='TheBritishLibrary', sha='37e47767e1b557bdc6ffbb37115d7784f8694f22', last_modified=datetime.datetime(2022, 11, 3, 16, 31, 29, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=554, likes=6, paperswithcode_id=None, tags=['task_categories:text-generation', 'task_categories:fill-mask', 'task_categories:other', 'task_ids:language-modeling', 'task_ids:masked-language-modeling', 'annotations_creators:no-annotation', 'language_creators:machine-generated', 'multilinguality:multilingual', 'size_categories:100K<n<1M', 'source_datasets:original', 'language:de', 'language:en', 'language:es', 'language:fr', 'language:it', 'language:nl', 'license:cc0-1.0', 'digital-humanities-research', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='TheBritishLibrary/blbooksgenre', author='TheBritishLibrary', sha='de087348b4ef8c44c2978f8ff819e9e3862089e6', last_modified=datetime.datetime(2023, 6, 1, 14, 59, 51, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=460, likes=4, paperswithcode_id=None, tags=['task_categories:text-classification', 'task_categories:text-generation', 'task_categories:fill-mask', 'task_ids:topic-classification', 'task_ids:multi-label-classification', 'task_ids:language-modeling', 'task_ids:masked-language-modeling', 'annotations_creators:expert-generated', 'language_creators:crowdsourced', 'language_creators:expert-generated', 'multilinguality:multilingual', 'size_categories:10K<n<100K', 'size_categories:1K<n<10K', 'source_datasets:original', 'language:de', 'language:en', 'language:fr', 'language:nl', 'license:cc0-1.0', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='blended_skill_talk', author=None, sha='877b97e51b588509da21d69572a3feac8334db7b', last_modified=datetime.datetime(2023, 4, 5, 9, 41, 47, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=669, likes=53, paperswithcode_id='blended-skill-talk', tags=['task_categories:conversational', 'task_ids:dialogue-generation', 'annotations_creators:crowdsourced', 'language_creators:crowdsourced', 'multilinguality:monolingual', 'size_categories:1K<n<10K', 'source_datasets:original', 'language:en', 'license:unknown', 'arxiv:2004.08449', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='blimp', author=None, sha='6ce3ab7c57eff25795892cf8056db91b1ed0e1ab', last_modified=datetime.datetime(2023, 4, 5, 9, 41, 50, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=36749, likes=30, paperswithcode_id='blimp', tags=['task_categories:text-classification', 'task_ids:acceptability-classification', 'annotations_creators:crowdsourced', 'language_creators:machine-generated', 'multilinguality:monolingual', 'size_categories:10K<n<100K', 'source_datasets:original', 'language:en', 'license:cc-by-4.0', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='blog_authorship_corpus', author=None, sha='728947f6c98ade87aa396004440cb3b58f173cb8', last_modified=datetime.datetime(2023, 6, 6, 16, 16, 13, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=419, likes=7, paperswithcode_id='blog-authorship-corpus', tags=['task_categories:text-classification', 'task_ids:multi-class-classification', 'annotations_creators:no-annotation', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:10K<n<100K', 'source_datasets:original', 'language:en', 'license:unknown', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='bn_hate_speech', author=None, sha='380262922e93586e4092c718580b9b1e8046bd8b', last_modified=datetime.datetime(2023, 1, 25, 14, 27, 23, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=969, likes=1, paperswithcode_id='bengali-hate-speech', tags=['task_categories:text-classification', 'annotations_creators:crowdsourced', 'annotations_creators:expert-generated', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:1K<n<10K', 'source_datasets:original', 'language:bn', 'license:mit', 'hate-speech-topic-classification', 'arxiv:2004.07807', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='bnl_newspapers', author=None, sha='6a222a2c64a6541fa1601af9f973f373616ae340', last_modified=datetime.datetime(2023, 1, 25, 14, 27, 26, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=193, likes=1, paperswithcode_id=None, tags=['task_categories:text-generation', 'task_categories:fill-mask', 'task_ids:language-modeling', 'task_ids:masked-language-modeling', 'annotations_creators:no-annotation', 'language_creators:found', 'multilinguality:multilingual', 'size_categories:100K<n<1M', 'source_datasets:original', 'language:ar', 'language:da', 'language:de', 'language:fi', 'language:fr', 'language:lb', 'language:nl', 'language:pt', 'license:cc0-1.0', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='bookcorpus', author=None, sha='4bc8a9f81f95682973a334ac59591200508773c5', last_modified=datetime.datetime(2023, 4, 5, 9, 41, 56, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=37093, likes=166, paperswithcode_id='bookcorpus', tags=['task_categories:text-generation', 'task_categories:fill-mask', 'task_ids:language-modeling', 'task_ids:masked-language-modeling', 'annotations_creators:no-annotation', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:10M<n<100M', 'source_datasets:original', 'language:en', 'license:unknown', 'arxiv:2105.05241', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='bookcorpusopen', author=None, sha='817f291474dcb4fa865ed7c8298e709cd8a20266', last_modified=datetime.datetime(2023, 11, 24, 14, 42, 8, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=313, likes=26, paperswithcode_id='bookcorpus', tags=['task_categories:text-generation', 'task_categories:fill-mask', 'task_ids:language-modeling', 'task_ids:masked-language-modeling', 'annotations_creators:no-annotation', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:10K<n<100K', 'source_datasets:original', 'language:en', 'license:unknown', 'arxiv:2105.05241', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='boolq', author=None, sha='223972799f5e6cfcab42fe099439930192bb9623', last_modified=datetime.datetime(2023, 4, 5, 9, 42, 1, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=23933, likes=30, paperswithcode_id='boolq', tags=['task_categories:text-classification', 'task_ids:natural-language-inference', 'annotations_creators:crowdsourced', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:10K<n<100K', 'source_datasets:original', 'language:en', 'license:cc-by-sa-3.0', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='bprec', author=None, sha='85c58974e811fb1496dc77e7e58187d4393f0d0b', last_modified=datetime.datetime(2023, 1, 25, 14, 27, 30, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=566, likes=0, paperswithcode_id=None, tags=['task_categories:text-retrieval', 'task_ids:entity-linking-retrieval', 'annotations_creators:expert-generated', 'language_creators:expert-generated', 'multilinguality:monolingual', 'size_categories:1K<n<10K', 'source_datasets:original', 'language:pl', 'license:unknown', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='break_data', author=None, sha='06f07116b91240aa0ff17e160caf99354601df60', last_modified=datetime.datetime(2023, 4, 5, 9, 42, 4, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=858, likes=0, paperswithcode_id='break', tags=['task_categories:text2text-generation', 'task_ids:open-domain-abstractive-qa', 'annotations_creators:crowdsourced', 'language_creators:crowdsourced', 'multilinguality:monolingual', 'size_categories:10K<n<100K', 'source_datasets:original', 'language:en', 'license:unknown', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='brwac', author=None, sha='56b613a900d088f45485bd5d9912794307686952', last_modified=datetime.datetime(2022, 11, 3, 16, 16, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=3908, likes=8, paperswithcode_id='brwac', tags=['task_categories:text-generation', 'task_categories:fill-mask', 'task_ids:language-modeling', 'task_ids:masked-language-modeling', 'annotations_creators:no-annotation', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:1M<n<10M', 'source_datasets:original', 'language:pt', 'license:unknown', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='bsd_ja_en', author=None, sha='0f75b3a3ff9b52d710721c95059bd821a8d37932', last_modified=datetime.datetime(2022, 11, 18, 19, 24, 36, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=337, likes=4, paperswithcode_id='business-scene-dialogue', tags=['task_categories:translation', 'annotations_creators:expert-generated', 'language_creators:expert-generated', 'multilinguality:translation', 'size_categories:10K<n<100K', 'source_datasets:original', 'language:en', 'language:ja', 'license:cc-by-nc-sa-4.0', 'business-conversations-translation', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='bswac', author=None, sha='818a0e388c429c0e54749e48fe1a8f6708809b28', last_modified=datetime.datetime(2022, 11, 3, 16, 15, 55, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=199, likes=0, paperswithcode_id=None, tags=['task_categories:text-generation', 'task_categories:fill-mask', 'task_ids:language-modeling', 'task_ids:masked-language-modeling', 'annotations_creators:no-annotation', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:100M<n<1B', 'source_datasets:original', 'language:bs', 'license:cc-by-sa-3.0', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='c3', author=None, sha='92d5052cbb5fd2cb1b58fe9b5e591f3d66e79772', last_modified=datetime.datetime(2022, 11, 18, 19, 24, 46, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=1068, likes=8, paperswithcode_id='c3', tags=['task_categories:question-answering', 'task_ids:multiple-choice-qa', 'annotations_creators:expert-generated', 'language_creators:expert-generated', 'multilinguality:monolingual', 'size_categories:1K<n<10K', 'source_datasets:original', 'language:zh', 'license:other', 'arxiv:1904.09679', 'region:us'], card_data=None, siblings=None),
# ...
#  DatasetInfo(id='GroNLP/ik-nlp-22_slp', author='GroNLP', sha='760fdc5d9fe699699025ff928ab6b5c631694238', last_modified=datetime.datetime(2023, 2, 1, 18, 25, 21, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=290, likes=0, paperswithcode_id=None, tags=['task_categories:question-answering', 'task_categories:summarization', 'task_categories:text-retrieval', 'annotations_creators:expert-generated', 'language_creators:expert-generated', 'multilinguality:monolingual', 'size_categories:1K<n<10K', 'source_datasets:original', 'language:en', 'license:unknown', 'question-generation', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='GroNLP/ik-nlp-22_transqe', author='GroNLP', sha='a632c66397917c1494b0bb090e2b2fa0b7e98868', last_modified=datetime.datetime(2022, 10, 21, 8, 6, 50, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=200, likes=0, paperswithcode_id=None, tags=['task_categories:text-classification', 'task_ids:natural-language-inference', 'annotations_creators:expert-generated', 'language_creators:expert-generated', 'language_creators:machine-generated', 'multilinguality:translation', 'size_categories:unknown', 'source_datasets:extended|esnli', 'language:en', 'language:nl', 'license:apache-2.0', 'quality-estimation', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='GroNLP/ik-nlp-22_winemag', author='GroNLP', sha='90eb39f35fc64e556fc17f06d4137a4a69ec3297', last_modified=datetime.datetime(2022, 2, 13, 11, 3, 27, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=196, likes=3, paperswithcode_id=None, tags=['license:cc-by-sa-4.0', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='HHousen/ParaSCI', author='HHousen', sha='5bbaa2ae85bfd49ac6ec872314d49a3b195a2f2b', last_modified=datetime.datetime(2021, 11, 24, 3, 38, 25, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=195, likes=1, paperswithcode_id=None, tags=['arxiv:2101.08382', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='HHousen/msrp', author='HHousen', sha='6b1694b6e20f25bd1236dd68ae3201b71a85d424', last_modified=datetime.datetime(2022, 1, 1, 3, 30, 43, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=221, likes=1, paperswithcode_id=None, tags=['region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='HHousen/quora', author='HHousen', sha='992115389a20fb16c43da344d4feae9cd396bf43', last_modified=datetime.datetime(2021, 11, 21, 2, 11, 20, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=1610, likes=1, paperswithcode_id=None, tags=['region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='HUPD/hupd', author='HUPD', sha='f570a84b03663180b6034c1f7f4c15864f94385e', last_modified=datetime.datetime(2022, 10, 24, 15, 47, 30, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=925, likes=21, paperswithcode_id=None, tags=['task_categories:fill-mask', 'task_categories:summarization', 'task_categories:text-classification', 'task_categories:token-classification', 'task_ids:masked-language-modeling', 'task_ids:multi-class-classification', 'task_ids:topic-classification', 'task_ids:named-entity-recognition', 'language:en', 'license:cc-by-sa-4.0', 'patents', 'arxiv:2207.04043', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='Halilyesilceng/autonlp-data-nameEntityRecognition', author='Halilyesilceng', sha='ae38fb811b5e1c418da3e65a256f625c78a29e8b', last_modified=datetime.datetime(2021, 3, 30, 23, 41, 25, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=98, likes=0, paperswithcode_id=None, tags=['region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='HarleyQ/WitcherDialogue', author='HarleyQ', sha='2e7d85ebef0840dc73708f104f2baa2dc660452f', last_modified=datetime.datetime(2021, 6, 2, 16, 15, 44, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=98, likes=0, paperswithcode_id=None, tags=['region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='HarrisDePerceptron/sv_corpora_parliament_processed', author='HarrisDePerceptron', sha='3dab36fe95dc28a7ef07239f7ace73ef4c97ca0a', last_modified=datetime.datetime(2022, 2, 6, 22, 8, 17, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=191, likes=0, paperswithcode_id=None, tags=['region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='HarrisDePerceptron/ur_corpora_pib', author='HarrisDePerceptron', sha='633d1915a5dfe168f3215b3404f610452f33bf45', last_modified=datetime.datetime(2022, 2, 8, 10, 30, 32, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=191, likes=0, paperswithcode_id=None, tags=['region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='Harveenchadha/bol-models', author='Harveenchadha', sha='5ce018508a7ce16c14e5a73d994daff438fcdc2d', last_modified=datetime.datetime(2021, 9, 17, 5, 51, 52, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=98, likes=0, paperswithcode_id=None, tags=['region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='Harveenchadha/indic-voice', author='Harveenchadha', sha='dcf5483845bfd6a068c708f434f69989a8161e20', last_modified=datetime.datetime(2023, 2, 26, 11, 42, 49, tzinfo=datetime.timezone.utc), private=False, gated='auto', disabled=False, downloads=1, likes=3, paperswithcode_id=None, tags=['annotations_creators:crowdsourced', 'language_creators:crowdsourced', 'multilinguality:multilingual', 'language:hi', 'language:mr', 'language:or', 'language:ta', 'language:te', 'language:gu', 'robust-speech-event', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='HarveyBWest/mybot', author='HarveyBWest', sha='6ba068d35eff5b785262fcc01b7a58706d4f97e9', last_modified=datetime.datetime(2021, 7, 3, 13, 22, 20, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=98, likes=0, paperswithcode_id=None, tags=['region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='Hellisotherpeople/DebateSum', author='Hellisotherpeople', sha='d65bea5f7a48f9af06453e855dbffe1753a0f508', last_modified=datetime.datetime(2022, 12, 3, 4, 14, 45, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=245, likes=9, paperswithcode_id=None, tags=['task_categories:question-answering', 'task_categories:summarization', 'task_categories:text-retrieval', 'task_categories:text-generation', 'task_ids:abstractive-qa', 'task_ids:document-retrieval', 'task_ids:extractive-qa', 'annotations_creators:expert-generated', 'language_creators:crowdsourced', 'multilinguality:monolingual', 'size_categories:100K<n<1M', 'source_datasets:original', 'language:en', 'license:mit', 'conditional-text-generation', 'arxiv:2011.07251', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='Helsinki-NLP/tatoeba_mt', author='Helsinki-NLP', sha='9635372e5421ccacda7db58e88741617867a9204', last_modified=datetime.datetime(2022, 10, 21, 15, 50, 25, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=74579, likes=43, paperswithcode_id=None, tags=['annotations_creators:no-annotation', 'language_creators:crowdsourced', 'multilinguality:translation', 'size_categories:unknown', 'source_datasets:original', 'language:af', 'language:ar', 'language:az', 'language:be', 'language:bg', 'language:bn', 'language:br', 'language:bs', 'language:ca', 'language:ch', 'language:cs', 'language:cv', 'language:cy', 'language:da', 'language:de', 'language:el', 'language:en', 'language:eo', 'language:es', 'language:et', 'language:eu', 'language:fa', 'language:fi', 'language:fo', 'language:fr', 'language:fy', 'language:ga', 'language:gd', 'language:gl', 'language:gn', 'language:he', 'language:hi', 'language:hr', 'language:hu', 'language:hy', 'language:ia', 'language:id', 'language:ie', 'language:io', 'language:is', 'language:it', 'language:ja', 'language:jv', 'language:ka', 'language:kk', 'language:km', 'language:ko', 'language:ku', 'language:kw', 'language:la', 'language:lb', 'language:lt', 'language:lv', 'language:mi', 'language:mk', 'language:ml', 'language:mn', 'language:mr', 'language:ms', 'language:mt', 'language:my', 'language:nb', 'language:nl', 'language:nn', 'language:no', 'language:oc', 'language:pl', 'language:pt', 'language:qu', 'language:rn', 'language:ro', 'language:ru', 'language:sh', 'language:sl', 'language:sq', 'language:sr', 'language:sv', 'language:sw', 'language:ta', 'language:te', 'language:th', 'language:tk', 'language:tl', 'language:tr', 'language:tt', 'language:ug', 'language:uk', 'language:ur', 'language:uz', 'language:vi', 'language:vo', 'language:yi', 'language:zh', 'license:cc-by-2.0', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='HenryAI/KerasAPIReference.txt', author='HenryAI', sha='945bea40d4783692fca28bb4fed101a57b922a2f', last_modified=datetime.datetime(2021, 12, 15, 15, 55, 7, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=191, likes=0, paperswithcode_id=None, tags=['region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='HenryAI/KerasBERTv1-Data', author='HenryAI', sha='80f81242d8d1cf1163018eab3b0237c8a12fcadd', last_modified=datetime.datetime(2021, 12, 15, 16, 5, 48, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=191, likes=0, paperswithcode_id=None, tags=['region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='HenryAI/KerasCodeExamples.txt', author='HenryAI', sha='2dd5beae4e31f10590a4860025d26edf36ac8512', last_modified=datetime.datetime(2021, 12, 15, 15, 57, 6, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=190, likes=0, paperswithcode_id=None, tags=['region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='HenryAI/KerasDeveloperGuides.txt', author='HenryAI', sha='8d270a68da1c0eedee946f5d7dc3261aab36237c', last_modified=datetime.datetime(2021, 12, 15, 15, 56, 47, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=98, likes=0, paperswithcode_id=None, tags=['region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='Huertas97/autonlp-data-mami-semeval-20-21', author='Huertas97', sha='d9d47ea79a409ccbeb15d64ffb3bd0621376551a', last_modified=datetime.datetime(2021, 10, 21, 8, 3, 52, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=191, likes=0, paperswithcode_id=None, tags=['region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='Husain/intent-classification-en-fr', author='Husain', sha='a6f1a20bd258f025dfa33e9e22ce4679b098e85a', last_modified=datetime.datetime(2021, 7, 28, 13, 6, 35, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=99, likes=0, paperswithcode_id=None, tags=['region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='IFSTalfredoswald/MBTI', author='IFSTalfredoswald', sha='16f3d2dbe10c17fed80f76ac6f757edacce7d82d', last_modified=datetime.datetime(2021, 10, 25, 10, 40, 2, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=191, likes=1, paperswithcode_id=None, tags=['region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='Iftoo95/Arabic_Sentiment_and_Topics', author='Iftoo95', sha='d858e3bf6145217b36e151636805daa733a77eb2', last_modified=datetime.datetime(2021, 11, 20, 14, 50, 45, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=100, likes=0, paperswithcode_id=None, tags=['region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='IlyaGusev/gazeta', author='IlyaGusev', sha='3faadb12ac1566f7944339cf5fb13f1066f9c5f7', last_modified=datetime.datetime(2023, 2, 12, 0, 1, 45, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=1783, likes=13, paperswithcode_id='gazeta', tags=['task_categories:summarization', 'annotations_creators:expert-generated', 'annotations_creators:found', 'language_creators:expert-generated', 'language_creators:found', 'multilinguality:monolingual', 'size_categories:10K<n<100K', 'source_datasets:original', 'language:ru', 'license:unknown', 'arxiv:2006.11063', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='IlyaGusev/headline_cause', author='IlyaGusev', sha='68c78423fe4653638a87ec91140488bb3cb97061', last_modified=datetime.datetime(2023, 2, 12, 0, 2, 58, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=499, likes=3, paperswithcode_id=None, tags=['task_categories:text-classification', 'task_ids:multi-class-classification', 'annotations_creators:crowdsourced', 'language_creators:found', 'multilinguality:multilingual', 'size_categories:10K<n<100K', 'source_datasets:original', 'language:ru', 'language:en', 'license:cc0-1.0', 'causal-reasoning', 'arxiv:2108.12626', 'region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='Intel/WEC-Eng', author='Intel', sha='e9a0f74a6fc2ec7a12ce66299dcffc693d2bf0d9', last_modified=datetime.datetime(2021, 10, 4, 11, 21, 48, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=190, likes=0, paperswithcode_id=None, tags=['region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='Ishwar/Senti', author='Ishwar', sha='dbcb8b0b3beca6fdbcbbb3d1aac0eb792c68e6b5', last_modified=datetime.datetime(2021, 10, 31, 10, 3, 41, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=190, likes=0, paperswithcode_id=None, tags=['region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='Iskaj/dutch_corpora_parliament_processed', author='Iskaj', sha='ed61af7c59e4f040796d8ca85c4f7d7d09f46ff7', last_modified=datetime.datetime(2022, 1, 27, 11, 42, 10, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=193, likes=0, paperswithcode_id=None, tags=['region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='JIWON/nil_dataset', author='JIWON', sha='b56c5975aceb95215cf62f0df0957290796f2038', last_modified=datetime.datetime(2022, 2, 7, 0, 34, 3, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=99, likes=0, paperswithcode_id=None, tags=['region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='JIsanan/war-ceb-wikipedia', author='JIsanan', sha='dad97e25cbb6fdbcf419d63d1bdbfa998978da60', last_modified=datetime.datetime(2021, 10, 24, 1, 48, 4, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=192, likes=0, paperswithcode_id=None, tags=['region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='Jack0508/TED2020_kor', author='Jack0508', sha='7afe7334bd7522452d36eaa131a6c3cfc2d78ae4', last_modified=datetime.datetime(2021, 11, 7, 19, 45, 21, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=193, likes=1, paperswithcode_id=None, tags=['region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='Jack0508/TED2020_vi', author='Jack0508', sha='aa5d105dd93ae17ade7786b73c926ac27d244b40', last_modified=datetime.datetime(2021, 11, 7, 19, 42, 16, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=194, likes=0, paperswithcode_id=None, tags=['region:us'], card_data=None, siblings=None),
#  DatasetInfo(id='Jack0508/TED2020vi_kor', author='Jack0508', sha='9764d8bff784eaa15a7f60ecef973159ffa0acd1', last_modified=datetime.datetime(2021, 11, 7, 17, 21, 21, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=193, likes=0, paperswithcode_id=None, tags=['region:us'], card_data=None, siblings=None),
#  ...]

# %%
dataset_infos[0].id.find('tion')
# Out:
# 18

# %%
for i, dataset_info in enumerate(dataset_infos):
    # if squad found
    if dataset_info.id.find("amazon_polarity") >= 0: 
        print(f"dataset_infos[{i}] is {dataset_info.id}")
# Out:
# dataset_infos[12] is amazon_polarity
# dataset_infos[1191] is SetFit/amazon_polarity
# dataset_infos[5015] is nouamanetazi/amazon_polarity
# dataset_infos[5029] is mteb/amazon_polarity
# dataset_infos[7143] is autoevaluate/autoeval-staging-eval-project-amazon_polarity-cff5f71a-10735440
# dataset_infos[7154] is autoevaluate/autoeval-staging-eval-project-amazon_polarity-80882a08-10755446
# dataset_infos[7901] is rungalileo/amazon_polarity_30k
# dataset_infos[7909] is rungalileo/amazon_polarity
# dataset_infos[10546] is autoevaluate/autoeval-eval-amazon_polarity-amazon_polarity-b95081-1665358869
# dataset_infos[14019] is autoevaluate/autoeval-eval-amazon_polarity-amazon_polarity-dc10d9-2205670760
# dataset_infos[62690] is atmallen/amazon_polarity_embeddings
# dataset_infos[62698] is atmallen/amazon_polarity_embeddings_random0
# dataset_infos[62717] is atmallen/amazon_polarity_embeddings_random1
# dataset_infos[62737] is atmallen/amazon_polarity_embeddings_random2
# dataset_infos[62755] is atmallen/amazon_polarity_embeddings_random3
# dataset_infos[62757] is atmallen/amazon_polarity_embeddings_random4
# dataset_infos[63937] is ben-epstein/amazon_polarity_10_pct
# dataset_infos[65165] is autoevaluate/autoeval-eval-amazon_polarity-amazon_polarity-d08caa-33166145013
# dataset_infos[65233] is autoevaluate/autoeval-eval-amazon_polarity-amazon_polarity-8d71e7-41666145077
# dataset_infos[65350] is autoevaluate/autoeval-eval-amazon_polarity-amazon_polarity-bf19c3-45203145158
# dataset_infos[65768] is autoevaluate/autoeval-eval-amazon_polarity-amazon_polarity-56b5a5-65818145567
# dataset_infos[65803] is autoevaluate/autoeval-eval-amazon_polarity-amazon_polarity-eccfe6-67532145600
# dataset_infos[65887] is autoevaluate/autoeval-eval-amazon_polarity-amazon_polarity-322a2a-70310145683
# dataset_infos[65888] is autoevaluate/autoeval-eval-amazon_polarity-amazon_polarity-e891a6-70311145684
# dataset_infos[65889] is autoevaluate/autoeval-eval-amazon_polarity-amazon_polarity-976ed0-70312145685
# dataset_infos[66833] is autoevaluate/autoeval-eval-amazon_polarity-amazon_polarity-afc8c5-93509145863
# dataset_infos[72017] is Domino-ai/amazon_polarity_10_pct
# dataset_infos[74065] is KETI-AIR/kor_amazon_polarity

# %%
from datasets import load_dataset

raw_datasets = load_dataset("amazon_polarity") 
raw_datasets # dictionary of datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'title', 'content'],
#         num_rows: 3600000
#     })
#     test: Dataset({
#         features: ['label', 'title', 'content'],
#         num_rows: 400000
#     })
# })

# %% [markdown]
# # Slicing

# %%
raw_datasets['train'][0] # dict
# Out:
# {'label': 1,
#  'title': 'Stuning even for the non-gamer',
#  'content': 'This sound track was beautiful! It paints the senery in your mind so well I would recomend it even to people who hate vid. game music! I have played the game Chrono Cross but out of all of the games I have ever played it has the best music! It backs away from crude keyboarding and takes a fresher step with grate guitars and soulful orchestras. It would impress anyone who cares to listen! ^_^'}

# %%
type(raw_datasets['train'][0])
# Out:
# dict

# %%
raw_datasets['train'][:3] # dict
# Out:
# {'label': [1, 1, 1],
#  'title': ['Stuning even for the non-gamer',
#   'The best soundtrack ever to anything.',
#   'Amazing!'],
#  'content': ['This sound track was beautiful! It paints the senery in your mind so well I would recomend it even to people who hate vid. game music! I have played the game Chrono Cross but out of all of the games I have ever played it has the best music! It backs away from crude keyboarding and takes a fresher step with grate guitars and soulful orchestras. It would impress anyone who cares to listen! ^_^',
#   "I'm reading a lot of reviews saying that this is the best 'game soundtrack' and I figured that I'd write a review to disagree a bit. This in my opinino is Yasunori Mitsuda's ultimate masterpiece. The music is timeless and I'm been listening to it for years now and its beauty simply refuses to fade.The price tag on this is pretty staggering I must say, but if you are going to buy any cd for this much money, this is the only one that I feel would be worth every penny.",
#   'This soundtrack is my favorite music of all time, hands down. The intense sadness of "Prisoners of Fate" (which means all the more if you\'ve played the game) and the hope in "A Distant Promise" and "Girl who Stole the Star" have been an important inspiration to me personally throughout my teen years. The higher energy tracks like "Chrono Cross ~ Time\'s Scar~", "Time of the Dreamwatch", and "Chronomantique" (indefinably remeniscent of Chrono Trigger) are all absolutely superb as well.This soundtrack is amazing music, probably the best of this composer\'s work (I haven\'t heard the Xenogears soundtrack, so I can\'t say for sure), and even if you\'ve never played the game, it would be worth twice the price to buy it.I wish I could give it 6 stars.']}

# %%
raw_datasets['train'][:3]['title']
# Out:
# ['Stuning even for the non-gamer',
#  'The best soundtrack ever to anything.',
#  'Amazing!']

# %%
raw_datasets['train']['title']
# Out:
# ['Stuning even for the non-gamer',
#  'The best soundtrack ever to anything.',
#  'Amazing!',
#  'Excellent Soundtrack',
#  'Remember, Pull Your Jaw Off The Floor After Hearing it',
#  'an absolute masterpiece',
#  'Buyer beware',
#  'Glorious story',
#  'A FIVE STAR BOOK',
#  'Whispers of the Wicked Saints',
#  'The Worst!',
#  'Great book',
#  'Great Read',
#  'Oh please',
#  'Awful beyond belief!',
#  "Don't try to fool us with fake reviews.",
#  'A romantic zen baseball comedy',
#  'Fashionable Compression Stockings!',
#  'Jobst UltraSheer Thigh High',
#  'sizes recomended in the size chart are not real',
#  'mens ultrasheer',
#  'Delicious cookie mix',
#  'Another Abysmal Digital Copy',
#  'A fascinating insight into the life of modern Japanese teens',
#  'i liked this album more then i thought i would',
#  'Problem with charging smaller AAAs',
#  'Works, but not as advertised',
#  'Disappointed',
#  'Oh dear',
#  "Based on the reviews here I bought one and I'm glad I did!",
#  'Incorrect disc!',
#  'happy with it...but',
#  'should be titled "Hollywood Debacle"',
#  'Is this great TV??? You bet it is',
#  "Nothing you don't already know",
#  "Unfortunately it wasn't entertaining in the least bit.",
#  'Rochelle explains It All for You',
#  'More great playing',
#  "Doesn't work on a Mac",
#  'Very Frustrating',
#  'Mind numbing',
#  'Cannot recommend',
#  'Alaska sourdough',
#  'Old and good',
#  'autumn',
#  'Fast mp3 download of music waxed decades ago',
#  'Maybe I got a bad one.',
#  'Sylvania 6620LDG 20" Flat Panel LCD TV with Built in DVD player',
#  'TERRIBLE!! DO NOT BUY THIS',
#  '*** BEWARE ***',
#  'Kitchen TV',
#  'Nice for the money',
#  'Disappointed Romanian!',
#  'Great travel guide to Europe!',
#  'Not the best',
#  'Good but received defective book',
#  'From The Label:',
#  'Either 1 or 5 Stars. Depends on how you look at it.',
#  'Hunting the Hard Way',
#  'Disappointing',
#  'Homer or Moses?',
#  'Very poor quality.',
#  'Scraped across the whole top.',
#  'unknown Africa',
#  "Didn't live up to expectations.",
#  'Profound then. Truly horrible now.',
#  'Definitely enjoyed!',
#  'Even Mommy has fun with this one!',
#  'Great combination of creativity and adventure',
#  'Rapunzel',
#  '[Not what I expected]',
#  'barbie rapunzel = crying child',
#  'Barbie as Rapunzel: A Creative Adventure',
#  'Use your imagination!',
#  'Not so good - ok for a rental!',
#  'NOT OS X but MAC CLASSIC',
#  'Bad Deal!!',
#  'Smells divine.',
#  'Very disappointed!',
#  'Creepy',
#  'audio options non existent',
#  "Sooo JAMMIN', too trill",
#  'Dirty South',
#  'Good book',
#  'voices from the farm',
#  'Little one, maid of Israel',
#  'It Drew Air',
#  'comfy,warm.. but run big',
#  'Buyer Beware!!',
#  'Ariel Litte Mermaid with pearl kit',
#  'No instructions included - do not trust seller',
#  'Why is SOULWAX ignored by critics & consumers alike?!',
#  'OMG Soulwax owns',
#  'Slow dull "classical" 1980\'s style movie',
#  'Thank you for Releasing it!!!!!',
#  'Very Not Worth Your Time',
#  'Very fun and educational',
#  'Ludicrous and silly',
#  'Artistry',
#  'Caution!',
#  'textbook',
#  'a great book for Historical romance lovers',
#  'YES!!!',
#  'Not the best in the series',
#  'ADDONICS PORTABLE CD DRIVE - I am disappointed in its performance',
#  'Too Uncomfortable and Too Big',
#  'Very authentic',
#  'Not the best',
#  "Doesn't Fit",
#  'You need a good memory',
#  'Kelly Club Pet Parade at HIT!! My Daughter Loves IT!!',
#  'Loads of fun!',
#  'easy and fun for 3-4yr olds',
#  'Hours of Fun for my 4 and 6 year olds',
#  'slip on 2 1/2 in. heel shoes',
#  'DDR is cooool!',
#  'Amazing',
#  'I got fooled...',
#  'I got fooled...',
#  'MORE THAN LETTERS...',
#  'Worth the wait!',
#  'letters from home',
#  'no good',
#  'ESTE LIBRO CONTIENE TODO',
#  'Oh!',
#  'Delicious and Addictive',
#  "Oh where Oh where have my Oh's gone?",
#  'One of a kind book for timber frame building.',
#  'no technical information',
#  'Hanford Mills museum',
#  'you will not be able to buils a timber frame house',
#  'Outstanding guidebook for building your own timberframe home',
#  'Excellent book, very poor e-book editing',
#  'A very good how-to manual.',
#  'Poor instructions, but once you figure it out... kinda cool',
#  'Great Graphics!',
#  'Dont run out to get Outrun unless your from 1985',
#  'My Henry',
#  'Henry has come home...',
#  'Charisma',
#  'I found it! Henry Dog!',
#  'A Contemporary Fairytale Sure to Delight!',
#  'Not Patterns - but Detailed Sketches',
#  'great gift',
#  "Product didn't match the picture/description",
#  'Good for a laugh',
#  'As Bad a Production as Possible',
#  'Not professional quality',
#  'three to four stars - depending...',
#  'Good songs, bad cover.',
#  'New Wave 80s',
#  "Don't Be Fooled!",
#  'Buyers Beware!!!!!!!!!',
#  'Sony basic Hi8 Handycam Rocks!',
#  'BEWARE!!',
#  "80's High Tech with Rock Emotion",
#  'Never gets going',
#  'Now, The Rest of the Story',
#  'The baseball benchmark',
#  'Perfect for the die-hard baseball fan',
#  '"Uh oh he\'s been using Brand X"',
#  'This was an intriguing book that influenced my destiny.',
#  'Peek a Fun!',
#  'Excellent product',
#  'Great for Twins',
#  "They're blocks - keep that in mind",
#  'Would have expected better!',
#  'Cute gift for a little baby',
#  'Great Blocks',
#  'Awesume! BEST BLOCKS EVER!',
#  'keeps his attention',
#  'Great value.',
#  'Wonderful but not worth $80.',
#  'Worth the investment',
#  'waste off money',
#  'California Exotics Waterproof Delights Blue Ballsy',
#  "small didn't work",
#  'Makes for fascinating reading.',
#  'Pretty Nifty!',
#  'Yet another unsubstantiated case....',
#  'Molly Myers',
#  'Gardening lawn book',
#  "It's a knock off.",
#  'Just a few.',
#  'It was "ok" but I won\'t watch it again',
#  'Loved it! (P.S. Stephen Colletti is so hot!)',
#  'mask maker',
#  'mask maker',
#  'NOT the worst American B-Movie',
#  'MASK OF FAMILIARITY',
#  'Unmasked..................',
#  'A museum exhibit inside a book',
#  'Great resource for Chinese/Eastern medincine',
#  'Why Is This A Good Book?',
#  'A Book That Is Worth a Second Look',
#  'Best game ever',
#  'Guitar in Absentia',
#  'Stiff and Smells like drying paint',
#  'Review of Pillow',
#  "Don't bother",
#  'Worthless and cheap',
#  'Will not be purchasing another one of these',
#  'False Advertisement',
#  'Not Like the Old Formula',
#  "haven't found better yet...",
#  'smoothing serum',
#  'The product I received this time is like fake one',
#  "If it ain't broke don't fix it",
#  'Review of Artec Textureline Smoothing Serum',
#  'LOVE IT!',
#  'The Best !!!!',
#  'Great control racquet',
#  'DO NOT BUY, A WASTE OF MONEY AND TIME!!!',
#  'Bad skating technique',
#  'A complete waste',
#  '4 year old BORED with this after 2 weeks',
#  "Barbie's Boring Ice Show",
#  'WHAT A WASTE OF MONEY! BARBIE HAS SUNK TO NEW LOWS',
#  "IT'S GREAT!",
#  'A good game to buy.',
#  'Great Game',
#  'Not really what I wanted',
#  'Rare find',
#  'Fire Truck Puzzle',
#  'Dark Horses a must have CD',
#  "Don't buy from Eforcity -- slow, disingenuous",
#  "Don't waste your money",
#  'Does not work!',
#  'Plug it in and it works!',
#  'MYSTICAL THINKMAN',
#  'The most charming, captivating work from LJ Smith!',
#  'Beautiful Love Story',
#  'The Best Yet!!!',
#  'The Best',
#  'Soul-mates',
#  'Possibly the Best out of this series!',
#  'Amazing!',
#  "One of the best books I've ever read!",
#  'Daughters of Darkness-THE BEST',
#  'One of her best in the Night World series!',
#  '2 Humans and 3 vampires after a vampire slayer',
#  "I'm hooked and I want some more ...",
#  'L.J. Smith has so many correct details....',
#  'It was great!!!',
#  'Disappointing',
#  'mirroring the reader',
#  "Don't Waste Yout Time",
#  'Thick, dry and packed full of somewhat useful information',
#  'Kylie takes a bite at subtlety....',
#  'A rare & wondeful treat',
#  'nifty',
#  'Grandson enjoyed maybe 20 times!',
#  'Very annoying!',
#  'Extremely Disappointed with this video',
#  'Just so-so',
#  'More than Thomas, Not Geared Toward Children As Much',
#  'A long promo for the Thomas center(s)',
#  'Poor DVD',
#  'My Son finds it annoying',
#  'Feels like a commercial...',
#  'Makes you not want to sleep at night.....',
#  "$25K warranty isn't included in packaging or at APC site",
#  'Great little surge protector',
#  'Too Small',
#  'A good product available in convenient range of sizes',
#  'TOM ATKINSON REVIEW',
#  'Cut smaller than usual',
#  'Wrong item sent.',
#  'Too bad....',
#  'Dockers do the job.',
#  'False advertising',
#  "Don't Trust the Images",
#  'So disappointed',
#  'Fantastic Book',
#  'Disturbing',
#  'A Taste of Italy',
#  'Perfect book for a long flight....',
#  'Delicious reading',
#  'Wonderfully romantic book that sweeps you to Italy',
#  'I just wanted to cook for my husband on those dark and stary nights...',
#  'One of the best!',
#  'Cameriere!',
#  'Food porn, and I mean that in the best possible way',
#  '"Chick Lit " for "Foodies"',
#  'Not very good....',
#  'Do not waste your time....lousy',
#  'The food is sexier than the sex',
#  'Back to basics',
#  'CASH MONEY AND NO LIMIT ARE THA SAME THANG!',
#  'Just as trashy as garbage music comes...',
#  'this album is garbage,straight bfi material',
#  'I feel ya "Ghenry187@aol"...this CD rocks. No Limit can\'t...',
#  'save your $$$',
#  "PLEASE DON'T BUY THIS CD!",
#  'Worst music ever....but I love it.',
#  'classic',
#  'NO, NOT 5 STARZ 6 STARZ!',
#  'THIS IS A ONE COMPARED TO JUVENILEZ 400 DEGREEZ',
#  'The worst rap I ever Heard',
#  'super hot',
#  'super wack',
#  'ghetto foolishness',
#  'Please try another Hot Boy album...',
#  'Fun To Listen To.',
#  'Did you like 400 degreez?',
#  'This CD iz Aight...........',
#  'Tha One',
#  'Short book explaining Love and Logic',
#  'Book review',
#  "A Novel as Enjoyable as the Restaurant Antoine's",
#  'An old friend',
#  'NOT A RIDE ON',
#  'Excellent - Very Useful',
#  'Wonderful. A thorough reference guide.',
#  'Fantastic Advanced Course!',
#  'Simply excellent !!! No Comparision',
#  'Complete reference... yes',
#  'Good place to start Web development',
#  'Keeps me healthy and I am not allergic to this brand.',
#  'Thoughtful, contemporary fiction',
#  'Why Some People Complain',
#  'My Daughter Hates It',
#  'glider',
#  'bench',
#  'Great Glider',
#  'Gauges in chair arms',
#  'Very nice glider',
#  'Fantastic glider/ bench',
#  'James Moody takes San Diego "Beyond the Border"!',
#  'Seal IV',
#  'Woburn: Forgotten Tales & Untold Stories',
#  'Too Much on the Mystical Plate',
#  "God's Zoo",
#  'Different',
#  'Awesome',
#  'An interesting little essay',
#  'Great Actors - Well done film!',
#  'Great movie, not so great DVD',
#  'an extreme emotional ride',
#  'Grrrrr. Arrrrgh.',
#  "I give it 5 stars because it's entombed",
#  'bye bye mom and dad',
#  'Bass - voice delight in jazz music',
#  'Danelectro DJ-20C Rocky Road Spin Speaker Mini Effects Pedal',
#  'Fabulous...',
#  'SHE HAS DONE IT AGAIN!!!!!!',
#  'Wonderful!!!',
#  'A change from the Carpathian Series',
#  'Riveting',
#  'Not her best...........',
#  'This one is missing that Feehan Spark',
#  'Intriguing story',
#  'amazing',
#  'Too Boring',
#  'Ick ack. Put it back.',
#  'disappointed',
#  'Not up to scratch!',
#  'WONDERFUL GOTHIC',
#  'YOU HAVE ANOTHER WINNER..... CONGRATULATIONS',
#  "An Old World change that's definitely wonderful",
#  'Great Reading',
#  "I really wish i hadn't wasted my time",
#  "Couldn't finish it",
#  'Poor support',
#  'Very Good',
#  'Great for the money',
#  'Low resolution and poor quality',
#  'Better than some out there.',
#  'Fun toy!',
#  'Cruel and Unusual',
#  'Good Deal and Fast Shipping',
#  '2/3 of a great book, then... blah',
#  'Review',
#  'Love Scarpetta',
#  'A really bad book',
#  'formula type writing',
#  'Just Plain Cruel Will Do',
#  'Cruel and Unusual',
#  'I guess it was a mystery',
#  'Inproper Advertising',
#  'Solid Addition to the Series',
#  'Still Loving Scarpetta',
#  'Great',
#  'Another one done!!!',
#  'Cruel and Unusual',
#  'Muddled ending disapoints',
#  'Spellbound!',
#  'Very nice book',
#  'Too scattered, too shallow',
#  'Soooooooooooo NOT Funny',
#  'Totally Unfunny',
#  'Nasty People! Nasty Film!',
#  'zero star',
#  'Dramedy',
#  'The Not so Funny People',
#  'What happend Sandler?',
#  'serious comedy',
#  'Long, somewhat dull and unfocused',
#  'WHICH JOKE DID YOU FIND FUNNY?',
#  'Far better than its reputation, and well worth a look',
#  'Starts out with promise, but then goes downhill.',
#  'Not so Funny people!',
#  "Obviously, not Adam Sandler's best",
#  'Not what I expected...',
#  "Couldn't give it less than one star....or i would've!!!!",
#  'Absolutely NOTHING Funny !',
#  "Worst movie I've ever seen",
#  'worst film ever',
#  'The L O N G E S T movie... EVER!',
#  'profanity the movie!!! or profanity and the degenerates.!!!',
#  "Seth Kept this movie from getting a 'ZERO' star rating!!",
#  'Stupid....',
#  "Sandler's worst!",
#  'Not good',
#  'GIFT',
#  'waste of time',
#  'Depressing then becomes boring',
#  'Please just run far FAR away from this film.',
#  'THE WORST MOVIE EVER MADE!!!',
#  'Moron',
#  'NOT FUNNY!',
#  'Pretty pathetic people',
#  'great movie, movie is longer than 2hours',
#  'Not entirely a comedy',
#  'Winning Cast, movie fell short',
#  'ACTUALLY NO STARS for rating pf Funny People movie',
#  'Not Funny People',
#  'Very inspirational',
#  "Sfar's Best!",
#  "The Rabbi's Cat is the cat's meow!",
#  'A wonderful, funny-sad book',
#  'good artwork too!',
#  "Delightful, exotic world seen through a cat's eyes",
#  'Self-Serving Message',
#  'Not what it looks like on the cover.',
#  'The Last dissenting Witness',
#  'See my article "Jean Hill - The Lady in Red" online',
#  'Drivel',
#  'An Ever expanding story followed by same ol same ol',
#  'Uneducated Nonsense',
#  'Great Swords for a Great Price!',
#  'Fraud,not as advertised',
#  'Impossible to read',
#  'Nice size',
#  "Still haven't received item",
#  'Curve',
#  'Good value',
#  'Unsatisfying ending disappoints the reader',
#  "The Best Patricia Cornwell's book",
#  'Kay Scarpetti is losing it.',
#  "If you can't say anything nice,",
#  'Great read',
#  'You have GOT to be kidding',
#  'My brain froze over',
#  'Losing her edge?',
#  'The devil in the detail',
#  'The pits . . . a contrived pot-boiler. Avoid it.',
#  'So far, the worst book of one of my favorite authors',
#  'Very Dissapointing',
#  'Intelligently written; a fast and suspenseful read.',
#  'What a disappointment!',
#  'Just awful',
#  'A wildly implausible thriller',
#  "From Potter's field, buried with no name",
#  'Impressive delivery but plot lacking in believability',
#  "No one will edit this, because I'm Patricia Cornwell",
#  'a let down',
#  'To contrived and therefore not plausible',
#  'Stilted and Hokey',
#  'Terror in Central Park',
#  'Patricia Cornwell rocks! Best mystery writer on record!',
#  'Rekindling Love',
#  'Worst English dub of a great TV series',
#  'A Piece of Crap!',
#  'No theory what so ever',
#  'You sure can tell this was written by an accountant...',
#  'wrong item',
#  'Worthless',
#  "There's no other book like this one!",
#  "Don't bother!",
#  'Lincoln and his time',
#  "Explains why economics and politics don't mix!",
#  'a brilliant, well-written economics primer',
#  "Don't waste your money.",
#  'More of a personal opinion than that of economics',
#  'Not what it claims to Be',
#  'The best book on Economics...',
#  '3.5 Stars-A useful supplementary text for lower division microeconomic principles courses only',
#  'Title is a Scam',
#  'NO Help',
#  'Polemic and Outdated',
#  'Too simplistic',
#  "This ain't no economics book!",
#  'No lessons learned',
#  'Best book on Economics for the general reader',
#  "If you don't have this, get it!",
#  'Read the angry anti-Hazlitt reviews for a real indication',
#  'Give this book to a your children.',
#  'ECONOMICS IN ONE LESSON',
#  'Never more needed than today',
#  'Economics even you will Understand',
#  'Simply brilliant!',
#  'One lesson that EVERYONE needs to learn!',
#  'Textbook',
#  'Our Senators and Reps should read and heed',
#  'Great Book',
#  'Painful',
#  'Unsatisfactory and very outdated',
#  "Don't Be Fooled By the Title of This Book",
#  'Hypocritical, Biased, outdated and misleading',
#  'Capitalism straight, in small unpalatable doses',
#  'Right-libertarian views presented as fact',
#  'ASTOUNDING',
#  'how to fail economics 101',
#  "Read this if You're Stupid and wish to be Fanatically Stupid",
#  'Back to basics...',
#  'A great alternative perspective',
#  'Sanity in Economics',
#  'Fine Summary',
#  'A good libertarian primer',
#  'Important',
#  'Economics',
#  'Frighteningly Prophetic',
#  'Great book',
#  'Great summary of some very difficult economic principles',
#  'over-simplified diatribe',
#  'More politics, less economincs',
#  "This book's title is misleading.",
#  'Seriously Flawed',
#  'Not a primer, way too political',
#  'Straight to the trash can!',
#  'Pretty cool',
#  'Allison rocks!',
#  'Kids love it',
#  'Great for kids!',
#  'Chocolate delicious by body hottie',
#  "A Stellar Kid's Tape!",
#  'Too much kid-pop music for a dark, animated movie!',
#  'TMNT Soundtrack',
#  'Egbert is such a wonderful name',
#  'sweet musings for loss and love',
#  'The Art of Chinese Medical Science',
#  'What more do I need?',
#  'A great American Sisters book.',
#  'not quite what I was expecting',
#  'Agressive, Wild, Experimental & Honnest poetry',
#  'Nineteen folktales of South and Central America',
#  'This book is incomprehensible',
#  "It wasn't very good!",
#  'Very boring',
#  'on order',
#  'Long torso but great product',
#  'Love This Item',
#  'Had some problems at first but now i love it',
#  'Good choice for getting a vintage look',
#  'Squeem works well',
#  'Too small - NO RETURNS',
#  'wow',
#  'Great!',
#  "Wasn't what I expected",
#  'great',
#  'a good smoother',
#  'Works Well!',
#  'squeem cincher',
#  'not really worth it',
#  'Great product; great seller!',
#  'Painful Experience',
#  'Great Product!',
#  'poor fit',
#  'Not recommended!',
#  'Gave me a waist, but just pushed my fat around',
#  'Advertized as "New" but arrives worn out',
#  'Great results, with some side effects...',
#  'Perfect for getting rid of pesky love handles',
#  'Upset',
#  'Falling apart',
#  'ahi',
#  'Incrediby difficult to put on',
#  'Squeem',
#  'A bit uncomfortable...',
#  'This is the one',
#  'really love it.',
#  'Wow!',
#  'Not the shape I was going for....',
#  'Bones',
#  'Magic',
#  'Wrong item shipped!!!!!',
#  'Sizing is Ridiculous',
#  'So what is the sizing?',
#  'Causes sweat that makes it unwearable!',
#  'best money I ever spent on shape wear',
#  'works great',
#  'Great at first...not so good over time',
#  'Recommend this',
#  'boning is not a plus',
#  'Pass',
#  'Love this!',
#  'Poor quality',
#  'Squeem Perfect Waist, Firm compression',
#  'Not the best shaper',
#  'It works, BUT....',
#  'squeem',
#  'Product defective after 1 day of use',
#  'a great buy!',
#  'No,No,No This is not for me.....',
#  "Can't Go Wrong With This Item!",
#  'Would be great but...',
#  'works but uncomfortable',
#  'Major let down!',
#  'Awsome!!',
#  'Wasnt worth',
#  'GREAT THERAPEUTICALLY AS WELL AS GREAT FOR FASHION!!!',
#  'Not so much',
#  'Burn Rubber on Me',
#  'Not worth the price...',
#  'Torture',
#  'Squeem',
#  "I'm very impressed so far",
#  'Not for everyone',
#  'Squeem:> A Combination of Scream and Squeeze?',
#  'excelent product!',
#  'Hard to put on',
#  'Why does everybody rave when....',
#  'Uncomfortable!',
#  'Great idea, poor design',
#  'best shapewear',
#  'Waste of time for me',
#  'Not OK!!!',
#  'Not worth the pain it causes',
#  'I love It!',
#  'disappointed',
#  'itchy',
#  'i love it..',
#  "Wow, Ow and What's that smell?",
#  'squeem is pretty good',
#  'Snug Fit',
#  'Poor quality and lousy customer service',
#  'IN THE TRASH IT GOES!!!!!',
#  'Very sturdy',
#  'Worked for 5 days then broke',
#  'does its job',
#  'Squeem',
#  'So Far So Good!',
#  'Makes me look like a i have a perfect hourglass figure',
#  'simple quick fix',
#  'A must have...',
#  'The squeem waist cincher',
#  "Wasn't that impressed........",
#  'Squeeeeeze into your clothes',
#  'Love it',
#  'Good product',
#  'Waste of money',
#  'I got burned after few hours wearing it',
#  'does not fit me!',
#  'Bulky, feels gross, not worth ordering',
#  'Caused damage to my stomach muscles!',
#  'Great product',
#  'Great product',
#  'Love it!!',
#  'very good',
#  'It worked for me..',
#  'Not what I expected',
#  'Too small',
#  'perfect',
#  'AMAZING',
#  'Its amazing!!!',
#  'Awesome!',
#  'Fall apart',
#  'Awesome!',
#  'Janes All the worlds aircraft 1996-7',
#  'Marie Antoinette -- What A Doll!',
#  'Dont order them in white or any light color',
#  'This is Disgusting',
#  'Happy yet Dissapointed',
#  'Legend of Dragoon Soundtrack',
#  'I just wanted Jimmy Ponder (too little guitar on this one)',
#  'Horrible',
#  'Negative Stars! Avoid like flesh eating bacteria!',
#  'Worst movie EVER!!!!',
#  'meh',
#  'Religion and profits',
#  'Ten gold bananas for Gorilla',
#  'The ending was great!',
#  'Finally on CD',
#  'WARNING: This is the worst book ever written',
#  'Edge of Danger',
#  'Edge of Danger',
#  'Actually, this book is not worth one star.',
#  "Not Worth The Reader's Time",
#  'Disappointing and too simplistic',
#  "Worst Book I've Ever Read",
#  'Formula Writing',
#  'Edge of Danger by Jack Higgins',
#  'Worst of theYear...or, maybe the decade',
#  'Writing on autopilot',
#  'Sophomoric at Best',
#  'A Waste of Time',
#  'Plenty of action',
#  'Good story- Poor writing',
#  'Do I have to give it 1-star?',
#  'Disappointment on every page',
#  'I would rather watch paint dry',
#  'Tired formula',
#  'This is not the Jack Higgins I know',
#  'Completely predictable',
#  'EXTREMELY SHALLOW',
#  'Cartoon Arab-Scottish Villain',
#  "Can't believe I read the whole thing",
#  "I'd rate it 0 stars if I could have...",
#  'A bad book, poorly written.',
#  'higgins disappoints',
#  'Poorly Written',
#  'A Disappointment',
#  'Horrible',
#  'Not worth the effort',
#  "Can't believe the publisher had nerve to issue this book",
#  'Disappointing and thin',
#  'Two Hacks',
#  'Just skip it',
#  'Worst "Live" recording I\'ve ever bought!',
#  'A Different Collection of Early Stuff',
#  'Great reference',
#  'Excellent Resource Book',
#  'Has NO value!',
#  "Really great 'baby book' for your 4-legged children",
#  'needs $$ upgrade',
#  'Only Windows XP and earlier Support',
#  'not very well written',
#  'Hypatia',
#  'Scarlett Letter',
#  'Boring....Ridiculously long chapters.',
#  'scarlet letter',
#  'The Scarlett Letter',
#  'A thorn in the side of literature.',
#  'A Moral Novel with a Mystery',
#  'Excellent Book',
#  'technical problems with cassettes',
#  'Mundane, Tedious, Just Plain Boring',
#  'Oh god kill me now, this book is BAD.',
#  'Absolute Waste of Time',
#  'A Tedious Read',
#  'Classic? Really?',
#  'This book was OK............',
#  "I've read better.",
#  'Awakening.',
#  'The Scarlett Letter',
#  'Great Condition, Almost Exactly What I Expected',
#  'Gripping',
#  'Good read, but hard to navigate ebook',
#  "Why 5 stars? Because there's no 6th",
#  'love it',
#  'remembered from High School (eons ago)',
#  'A Classic',
#  'Typos',
#  'Decent book, but definately not Hanry David Theraou',
#  'Boring',
#  'Hi',
#  "It's great.",
#  'The scarlet Letter',
#  'Review From One Book At A Time',
#  'Amazingly Good',
#  'interesting book',
#  'Not my idea of a good read',
#  'Good book to read if you were bored to death!',
#  'A well written book!!',
#  'The Scarlett Letter is too verbose.',
#  'Bad Book',
#  'Duller than dirt',
#  'I must say',
#  'too hard to follow',
#  'Historically accurate it may be, but a boring read.',
#  'Wonderful classic',
#  'Worth the effort',
#  'Puritanical ostracism',
#  'Wasted Time',
#  'Tragic',
#  'Great',
#  "It's nice",
#  'Classic tale',
#  'A Classic Worth Reading',
#  'DO NOT READ THIS BOOK!!!!',
#  'My favorite classic',
#  'Scarlet Letter review',
#  'Excellent romance in an excellent edition',
#  'The Scarlet Letter is a really good piece of Literature',
#  'Terrible book, do not read it.',
#  'Meaningless Drivel',
#  'Worst. Book. Ever.',
#  'Who Chooses Classics?',
#  '"Hallelujah!" is what I said when I finished this book',
#  'a must read',
#  'Teachers: This is not his best novel',
#  'Very good and very unlike the movie',
#  'not kindle ready',
#  'good',
#  'Boring, very',
#  'Boring',
#  'Really Hard to Follow',
#  "A fascinating look into another time's mores",
#  'One word: outdated',
#  'I was fored to read it too',
#  'a tragedy',
#  'too had to read',
#  'Simply the worse book ever.',
#  'No Active Table of Contents',
#  'Should not be a requirement in high school',
#  "It was like a bad dream, but I couldn't wake up",
#  'Landscape book',
#  'THE SIMPLE CONCEPT OF SIN, TABOO',
#  'Excellent gift',
#  'Great classic for the price',
#  'Missing Custom House',
#  'Incredibly engrossing',
#  'Characterization in The Scarlet Letter',
#  'the illiteracy of our generation',
#  'The Scarlet Letter e-Book',
#  "I just don't get it.",
#  'favorite classic',
#  'Childish Novel',
#  'Jeff the Scorned',
#  'Ugh.',
#  'This book was dumb',
#  'Avg. Rating too high',
#  'Received a different book',
#  'Oh my...',
#  'Far too little crime and fist fights',
#  'Get to the point already',
#  'Slow moving predictable story',
#  'Good book if you look into it.',
#  'Great!!!!!READ ME READ ME READ ME!!!',
#  'Horrific forced reading',
#  'I read to pages of this novel and I had to stop!',
#  "I don't get it.",
#  'I hate this book.',
#  'its as if I were reading the book itself.',
#  'Way too boring for me',
#  'Great plot, horrible writing!!!!!!!!',
#  'get it away',
#  'Overrated Pretentious Trash',
#  'The Scarlet Letter',
#  'A classic novel with a contemporary message',
#  'Each read is like peeling layers of a rose',
#  'A better read as an adult -- not a great choice for teenagers...',
#  "Don't pay for this on the Kindle",
#  'Strong Woman',
#  'Slow, Overwritten Drama',
#  'Great Story ... Bad writing',
#  'Wonderful, wonderful',
#  'Awful',
#  'So boring',
#  'The okay book',
#  'I HATE THIS BOOK',
#  "Don't READ THIS BOOK!!",
#  'If your looking to fall asleep than this is perfect 4 you !',
#  'slowly falling asleep',
#  "one of the worst books I've ever read",
#  'I only gave it a star because I had to.',
#  'paralyzing fear',
#  'A sin to humanity',
#  'forced to read the most horrible book ever',
#  'This book is a wast of good paper',
#  'scarlet letter',
#  'Looooooooooooooooong.',
#  'Unable to Review',
#  'Painful',
#  'Incredibly confusing; have a dictionary on hand!',
#  'Save Yourself',
#  'Ick.',
#  'confusing, but good',
#  'SAD',
#  'The Next Best Thing to a Sleeping Pill!',
#  'great!',
#  'Beautifully Done',
#  'Not What it is Made Out to be...',
#  'hate this new format',
#  'Wonderful',
#  'Need a dictionary!',
#  'An Excellent Portait of Puritan New England',
#  'Leave this one to the bibliophiles',
#  'Yes, I was another victim who had to read this for school',
#  'a book value',
#  'Good read................. ............... .... ....... ........ .......... ......... ......... ......... ......... ..... .....',
#  'Not interesting at all',
#  'This book is incredibly boring!',
#  'Both forward and backward in its ideas',
#  'I am going to bring Hawthorne back from the grave to hit him',
#  'Not Worth Reading',
#  'Power to women',
#  'it was very slow.',
#  "It wasn't good",
#  'ugh',
#  'A classic...but one of the worst books, ever.',
#  'How Can Sex and Sin Be So Boring?',
#  'unfinishable',
#  'American classic my ...',
#  "Hawthorne's Masterpiece",
#  'Useful for AP Lit',
#  'Timeless Classic',
#  'One of the Greatest Books Ever Written',
#  'Does not have true plumeria scent',
#  'Just as described',
#  'The ultimate for women',
#  'Boring',
#  'Dual Language- Selections from Don Quixote',
#  'Best one in Tomato Trilogy',
#  'Pretty Fricken Sweet',
#  'FT rules',
#  '100 times better than the first',
#  'Too Stupid',
#  'DECEPTION!',
#  'Warning: You are not downloading Little Steven',
#  'Warming Dishs Sooooo Helpful',
#  'Not what we expected',
#  'Not user friendly',
#  'Not worth it',
#  'Great warming dish',
#  'NOT USER FREINDLY',
#  'Disappointed',
#  "Not User Friendly. NOTHING that says it's BPA-free",
#  'Sassy Baby Warming Dish vs. Gerber Bowl',
#  'just what i was looking for',
#  "Must-Have for Children's Library",
#  'Very informative',
#  '...',
#  '1996 edition of book is outdated',
#  'Disappointing',
#  'Arrived broken!',
#  'complicated',
#  'junk',
#  'entertaining, but not for everybody',
#  'Adam Sandler lame as ever...',
#  'One of the worst I have ever seen',
#  'Nauseating!',
#  'Spare yourself.',
#  "Adam Sandler's eight crazy nights",
#  'A very disappointing movie',
#  '8 Crazy Nights',
#  'Clean it up!',
#  '1 star, since there\'s no "zero stars" available',
#  'Eight Crazy Nights',
#  "Parents - Don't Let Your Kids Watch This Movie",
#  'sandler is da bomb',
#  'The thrid in a string of flops for Sandler',
#  'i want my money back',
#  'terrible movie',
#  'Not a Good Hanukkah or Christams Movie!',
#  'The worst movie ever made',
#  'ive seen this before...........',
#  'ugh',
#  'Awesome',
#  'Hilarious',
#  'Adam Sandler is Awesome',
#  'Crazy about 8 Crazy Nights!',
#  'Childrens Humor Not Suitable For Children.',
#  'Nightmare Before Hannukah',
#  'Okay. There is a movie worse than Stargate.',
#  "Worse Movie I've Seen In Ages",
#  'To be honest....',
#  'Sucks',
#  'return to forever proto-type',
#  'Inappropriate for young children',
#  'DVD Features',
#  'My little Thomas fan loves this DVD!',
#  'yo ho ho',
#  'Illegible',
#  'The only boots my husband will wear',
#  'Why so expensive??!',
#  'Spun Out',
#  'The Road To Love Is Full Of Danger Signs...',
#  'Who else would have three beautiful women after him?',
#  "Presley's Worst Film",
#  "The music's better than the movie",
#  'NOT A GOOD SPIN FOR PRESLEY',
#  'Spinout',
#  'Piece of junk!',
#  'Works and is easy to use',
#  'Great Buy!',
#  'Great Desk!',
#  'good quality for price',
#  'Great desk and a great buy! Thanks Amazon:)',
#  'Love KidKraft',
#  'Great Value for Less Money',
#  'very nice',
#  'Very Satisfied',
#  'Great value for good quality product',
#  "If it's good enough for Popeye...",
#  'A Must Have for ALL Aspects of Love Devotees!',
#  'Cheap and dangerous',
#  'Skip it - buy the full sized version',
#  'Slow',
#  'Multilevel marketing meets education',
#  'Well-Researched, easy to read, practical',
#  '"Pop" psychology at its worse...',
#  'Get off the dead horse of "old school" education',
#  'Easy read for brain information',
#  'Fuzzy around the edges',
#  'Brain Based Learning: The New Paradigm of Teaching',
#  'Brain based Learning',
#  'Pop psychology at its worst',
#  '"Science"',
#  ...]

# %%
raw_datasets['train'] # Dataset
# Out:
# Dataset({
#     features: ['label', 'title', 'content'],
#     num_rows: 3600000
# })

# %% [markdown]
# # map

# %%
raw_datasets['train'][:3]['title']
# Out:
# ['Stuning even for the non-gamer',
#  'The best soundtrack ever to anything.',
#  'Amazing!']

# %%
len(raw_datasets['train']), len(raw_datasets['test'])
# Out:
# (3600000, 400000)

# %% [markdown]
# DatasetDict has map method

# %%
def lower(examples):
    lower_text = examples['title'].lower()
    return {'title': lower_text}

from datasets import DatasetDict, Dataset

train_dataset = Dataset.from_dict(raw_datasets['train'][:100]) 
test_dataset = Dataset.from_dict(raw_datasets['test'][:100])
dsd = DatasetDict({"train": train_dataset, "test": test_dataset}) 
 
lowered_dsd = dsd.map(lower)
lowered_dsd
# Out:
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'title', 'content'],
#         num_rows: 100
#     })
#     test: Dataset({
#         features: ['label', 'title', 'content'],
#         num_rows: 100
#     })
# })

# %%
lowered_dsd['train'][:3]['title']
# Out:
# ['stuning even for the non-gamer',
#  'the best soundtrack ever to anything.',
#  'amazing!']

# %%
lowered_dsd['test'][:3]['title']
# Out:
# ['great cd',
#  "one of the best game music soundtracks - for a game i didn't really play",
#  'batteries died within a year ...']

# %% [markdown]
# dataset also has map method

# %%
lowered_train_dataset = train_dataset.map(lower)
lowered_train_dataset
# Out:
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# Dataset({
#     features: ['label', 'title', 'content'],
#     num_rows: 100
# })

# %%
lowered_train_dataset[:3]['title']
# Out:
# ['stuning even for the non-gamer',
#  'the best soundtrack ever to anything.',
#  'amazing!']

# %%
# dataset has format attribute
train_dataset.format
# Out:
# {'type': None,
#  'format_kwargs': {},
#  'columns': ['label', 'title', 'content'],
#  'output_all_columns': False}

# %%
# get item using PythonFormat
train_dataset[:3]
# Out:
# {'label': [1, 1, 1],
#  'title': ['Stuning even for the non-gamer',
#   'The best soundtrack ever to anything.',
#   'Amazing!'],
#  'content': ['This sound track was beautiful! It paints the senery in your mind so well I would recomend it even to people who hate vid. game music! I have played the game Chrono Cross but out of all of the games I have ever played it has the best music! It backs away from crude keyboarding and takes a fresher step with grate guitars and soulful orchestras. It would impress anyone who cares to listen! ^_^',
#   "I'm reading a lot of reviews saying that this is the best 'game soundtrack' and I figured that I'd write a review to disagree a bit. This in my opinino is Yasunori Mitsuda's ultimate masterpiece. The music is timeless and I'm been listening to it for years now and its beauty simply refuses to fade.The price tag on this is pretty staggering I must say, but if you are going to buy any cd for this much money, this is the only one that I feel would be worth every penny.",
#   'This soundtrack is my favorite music of all time, hands down. The intense sadness of "Prisoners of Fate" (which means all the more if you\'ve played the game) and the hope in "A Distant Promise" and "Girl who Stole the Star" have been an important inspiration to me personally throughout my teen years. The higher energy tracks like "Chrono Cross ~ Time\'s Scar~", "Time of the Dreamwatch", and "Chronomantique" (indefinably remeniscent of Chrono Trigger) are all absolutely superb as well.This soundtrack is amazing music, probably the best of this composer\'s work (I haven\'t heard the Xenogears soundtrack, so I can\'t say for sure), and even if you\'ve never played the game, it would be worth twice the price to buy it.I wish I could give it 6 stars.']}

# %%
train_dataset.set_format('pandas')
train_dataset.format
# Out:
# {'type': 'pandas',
#  'format_kwargs': {},
#  'columns': ['label', 'title', 'content'],
#  'output_all_columns': False}

# %%
# get item using pandasFormat
train_dataset[:5]
# Out:
#    label                                              title  \
# 0      1                     Stuning even for the non-gamer
# 1      1              The best soundtrack ever to anything.
# 2      1                                           Amazing!
# 3      1                               Excellent Soundtrack
# 4      1  Remember, Pull Your Jaw Off The Floor After He...
#
#                                              content
# 0  This sound track was beautiful! It paints the ...
# 1  I'm reading a lot of reviews saying that this ...
# 2  This soundtrack is my favorite music of all ti...
# 3  I truly like this soundtrack and I enjoy video...
# 4  If you've played the game, you know how divine...

# %%
type(train_dataset[:5])
# Out:
# pandas.core.frame.DataFrame

# %%
train_dataset.reset_format()
train_dataset.format
# Out:
# {'type': None,
#  'format_kwargs': {},
#  'columns': ['label', 'title', 'content'],
#  'output_all_columns': False}

# %%
train_dataset[:5]
# Out:
# {'label': [1, 1, 1, 1, 1],
#  'title': ['Stuning even for the non-gamer',
#   'The best soundtrack ever to anything.',
#   'Amazing!',
#   'Excellent Soundtrack',
#   'Remember, Pull Your Jaw Off The Floor After Hearing it'],
#  'content': ['This sound track was beautiful! It paints the senery in your mind so well I would recomend it even to people who hate vid. game music! I have played the game Chrono Cross but out of all of the games I have ever played it has the best music! It backs away from crude keyboarding and takes a fresher step with grate guitars and soulful orchestras. It would impress anyone who cares to listen! ^_^',
#   "I'm reading a lot of reviews saying that this is the best 'game soundtrack' and I figured that I'd write a review to disagree a bit. This in my opinino is Yasunori Mitsuda's ultimate masterpiece. The music is timeless and I'm been listening to it for years now and its beauty simply refuses to fade.The price tag on this is pretty staggering I must say, but if you are going to buy any cd for this much money, this is the only one that I feel would be worth every penny.",
#   'This soundtrack is my favorite music of all time, hands down. The intense sadness of "Prisoners of Fate" (which means all the more if you\'ve played the game) and the hope in "A Distant Promise" and "Girl who Stole the Star" have been an important inspiration to me personally throughout my teen years. The higher energy tracks like "Chrono Cross ~ Time\'s Scar~", "Time of the Dreamwatch", and "Chronomantique" (indefinably remeniscent of Chrono Trigger) are all absolutely superb as well.This soundtrack is amazing music, probably the best of this composer\'s work (I haven\'t heard the Xenogears soundtrack, so I can\'t say for sure), and even if you\'ve never played the game, it would be worth twice the price to buy it.I wish I could give it 6 stars.',
#   "I truly like this soundtrack and I enjoy video game music. I have played this game and most of the music on here I enjoy and it's truly relaxing and peaceful.On disk one. my favorites are Scars Of Time, Between Life and Death, Forest Of Illusion, Fortress of Ancient Dragons, Lost Fragment, and Drowned Valley.Disk Two: The Draggons, Galdorb - Home, Chronomantique, Prisoners of Fate, Gale, and my girlfriend likes ZelbessDisk Three: The best of the three. Garden Of God, Chronopolis, Fates, Jellyfish sea, Burning Orphange, Dragon's Prayer, Tower Of Stars, Dragon God, and Radical Dreamers - Unstealable Jewel.Overall, this is a excellent soundtrack and should be brought by those that like video game music.Xander Cross",
#   "If you've played the game, you know how divine the music is! Every single song tells a story of the game, it's that good! The greatest songs are without a doubt, Chrono Cross: Time's Scar, Magical Dreamers: The Wind, The Stars, and the Sea and Radical Dreamers: Unstolen Jewel. (Translation varies) This music is perfect if you ask me, the best it can be. Yasunori Mitsuda just poured his heart on and wrote it down on paper."]}

# %%
type(train_dataset)
# Out:
# datasets.arrow_dataset.Dataset
